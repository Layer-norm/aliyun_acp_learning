# %% [markdown]
# # 2.3 优化提示词改善答疑机器人回答质量

# %% [markdown]
# ## 🚄 前言

# %% [markdown]
# 上一节，你学习了**上下文工程 (Context Engineering)** 的一种关键技术——RAG，通过为大模型提供外部知识来扩展其能力。但这仅仅是构建优秀用户体验的第一步。用户往往期待更个性化、更精准的交互。
#
# 本节将深入探索上下文工程的另一重要方面：如何通过优化**提示词 (Prompt)** 来精细地控制大模型的输出，例如调整语气、规范格式，甚至赋予它处理文本总结、推断、转换等多种任务的能力。

# %% [markdown]
# ## 🍁 课程目标
#
# 学完本节课程后，你将能够：
#
# * 了解提示词框架和模板
# * 了解提示词技巧和最佳实践
# * 学习在工程中应用大模型处理多种不同类型的任务

# %% [markdown]
# ## 1. 前文回顾
#
# 上一节中通过RAG方法，大模型已经获取到了公司的私有知识。为了方便调用，将其封装成了几个函数，并保存在了 chatbot/rag.py 中。 现在你可以通过如下代码来快速调用。

# %%
import os

# 环境变量中指定 base_url
os.environ["BASE_URL"] = "https://dashscope.aliyuncs.com/compatible-mode/v1"

from config.load_key import load_key,load_nltk
# 加载API密钥
load_key()
print(f'''你配置的 API Key 是：{os.environ["DASHSCOPE_API_KEY"][:5]+"*"*5}''')
load_nltk()
# Out:
# 你配置的 API Key 是：sk-40*****
# 💡 环境检查：离线资源已在 \mnt\workspace\llm_learn\nltk_data\_static\nltk_cache 就绪。

# %%
from chatbot import rag, llm
# 加载索引
# 上小节已经建立了索引，因此这里可以直接加载索引。如果需要重建索引，可以增加一行代码：rag.indexing()
index = rag.load_index()
query_engine = rag.create_query_engine(index=index)
# Out:
# i:\myproject2026\aliyun_acp_learning\.venv\Lib\site-packages\pydantic\_internal\_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'validate_default' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'validate_default' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# Loading llama_index.core.storage.kvstore.simple_kvstore from knowledge_base/test\docstore.json.
# Loading llama_index.core.storage.kvstore.simple_kvstore from knowledge_base/test\index_store.json.

# %%
# 定义问答函数
def ask_llm(question, query_engine):
    streaming_response = query_engine.query(question)
    streaming_response.print_response_stream()

# %% [markdown]
# ## 2. 优化提示词以改善大模型回答质量
#
# 上一节，你已经成功地让答疑机器人通过 RAG 掌握了公司的内部知识。现在，你可以测试一下它的实际效果。一位新同事想了解项目管理工具，于是他向机器人发起了提问：

# %%
# 仅使用RAG时，机器人的表现
question = "我们公司项目管理应该用什么工具？"
ask_llm(question, query_engine)
# Out:
# 根据岗位指导说明书，项目管理应使用 Jira 或 Trello。

# %% [markdown]
# 预期输出（示例）：
# ```
# 公司项目管理可以使用Jira或Trello等项目管理软件。这些工具能够帮助团队更好地规划和跟踪项目的进度，确保任务按时完成。同时，它们还支持任务分配、时间跟踪和团队协作等功能，有助于提高工作效率。
# ```

# %% [markdown]
# 这个回答是正确的，但不够“好用”。同事反馈说：“如果能直接附上工具的链接就完美了，省得我再去到处找。”
#
# 这个需求非常合理。一个最直观、最“暴力”的解决方法，或许是在用户的问题后面，手动加上一句指令：

# %%
# 尝试一个简单的“补丁”
question = "我们公司项目管理应该用什么工具？"
instruction = " 回答时请务必附带上工具的官方网站或下载链接。"
 
# 将问题和指令简单地拼接在一起
new_question = question + instruction
ask_llm(new_question, query_engine)
# Out:
# 根据岗位指导说明书，项目管理推荐使用的工具包括 Jira 和 Trello。
#
# - **Jira**：官方网站为 [https://www.atlassian.com/software/jira](https://www.atlassian.com/software/jira)
# - **Trello**：官方网站为 [https://trello.com](https://trello.com)

# %% [markdown]
# 预期输出（示例）：
# ```
# 对于项目管理，推荐使用 Jira 或 Trello。这两个工具都非常适合管理和跟踪项目进度，确保团队成员之间的高效协作。
#
# - **Jira** 是一个非常强大的项目管理工具，特别适用于软件开发项目。它可以帮助你跟踪问题和任务，管理项目进度。你可以访问 [Atlassian官网](https://www.atlassian.com/software/jira) 获取更多信息或下载。
#
# - **Trello** 则是一个更加灵活的看板式项目管理工具，适合各种类型的项目。通过卡片和列表的形式，可以直观地看到项目的进展。你可以访问 [Trello官网](https://trello.com/) 获取更多信息或注册使用。
# ```

# %% [markdown]
# 问题似乎解决了。但……真的解决了吗？
#
# 你需要考虑另一个场景，当用户问一个跟工具无关的问题时：

# %%
# 看看这个“补丁”在其他问题上的表现
question_2 = "我们公司的年假有多少天？"
instruction = " 回答时请务必附带上工具的官方网站或下载链接。"
 
new_question_2 = question_2 + instruction
ask_llm(new_question_2, query_engine)
# Out:
# 根据提供的上下文信息，未提及公司年假的具体天数。同时，上下文中也未包含任何工具的官方网站或下载链接。
#
# 因此，无法回答“我们公司的年假有多少天”，也无法附上相关工具的官网或下载链接。

# %% [markdown]
# 预期输出（示例）：
# ```
# 您的问题涉及到具体的公司福利政策，特别是年假天数，但提供的信息中并没有直接提到这一点。通常这类详细信息会记录在员工手册或者公司内部的人力资源政策文件中。建议您直接联系人力资源部获取准确的信息。人力资源部的联系人是熊伟，您可以发送邮件至xiongwei@educompany.com询问具体事宜。
#
# 至于您要求的工具官方网站或下载链接，由于您的问题并未提及需要使用哪个工具，因此无法提供相关链接。
# ```

# %% [markdown]
# 现在，问题暴露了。这种“一刀切”地拼接指令的方式非常脆弱。它不仅可能让模型的回答变得啰嗦和奇怪，而且每次提问都要手动判断该拼接哪句指令，这在真实的应用中是完全不可行的。
#
# **这正是深入学习提示词工程（Prompt Engineering）的原因**。 它属于 **上下文工程（Context Engineering）** 的一部分，教你如何不再使用这种临时的“补丁”，而是系统性地、智能地构建与模型的对话上下文，精确地“指导”模型如何根据不同的情况来回答问题。

# %% [markdown]
# ## 3. 提示词框架
#
# ### 3.1 基本要素
#
# 当和大模型在交流时，可以将它想象是一个经过“社会化训练的”人，交流方式应当和人与人之间传递信息的方式一样。你的需求需要清晰明确，不能有歧义。你的提问方式（Prompt）越清晰明确，大模型越能抓住问题的关键点，回复就越符合你的预期。为了系统性地构建高效的上下文，我们可以遵循一个包含多个基本要素的提示词框架：**任务目标、上下文、角色、受众、样例、输出格式**。这些要素共同构成了一个完整的上下文“蓝图”，能帮助你构建一个完整、有效的提示词。
#
# |要素|含义|
# |----|----|
# |任务目标（Object）|明确要求大模型完成什么任务，让大模型专注具体目标|
# |上下文（Context）|任务的背景信息，比如操作流程、任务场景等，明确大模型理解讨论的范围|
# |角色（Role）|大模型扮演的角色，或者强调大模型应该使用的语气、写作风格等，明确大模型回应的预期情感|
# |受众（Audience）|明确大模型针对的特定受众，约束大模型的应答风格|
# |样例（Sample）|让大模型参考的具体案例，大模型会从中抽象出实现方案、需要注意的具体格式等信息|
# |输出格式（Output Format）|明确指定输出的格式、输出类型、枚举值的范围。通常也会明确指出不需要输出的内容和不期望的信息，可以结合样例来进一步明确输出的格式和输出方法|

# %% [markdown]
# 当然，除了上面讲的提示词框架，许多问题分析的思维范式都可以用来帮助你描述清晰具体的需求。例如，SWOT分析法、5W2H分析法等。另外，你也可以考虑使用阿里云百炼提供的[提示词自动优化工具](https://bailian.console.aliyun.com/?tab=app#/component-manage/prompt/optimize)，来帮助你完善提示词。
#
# <a href="https://img.alicdn.com/imgextra/i3/O1CN014JCCqn22zX6xB4tt3_!!6000000007191-0-tps-2068-1052.jpg" target="_blank">
# <img src="https://img.alicdn.com/imgextra/i3/O1CN014JCCqn22zX6xB4tt3_!!6000000007191-0-tps-2068-1052.jpg" width="700"/>
# </a>

# %% [markdown]
# ### 3.2 提示词模板
#
# 在开发大模型应用时，直接让用户根据框架书写提示词并非最佳选择。你可以参考各种提示词框架中的要素，构建一个提示词模板。提示词模板可以预设部分信息，如大模型的角色、注意事项等，以此来约束大模型的行为。开发者只需在模板中配置输入参数，便能创建标准化的大模型的应用。

# %% [markdown]
# 使用 LlamaIndex 中创建的 RAG应用中，有个默认的提示词模板，如下所示：
#
# - 默认的模板可以使用代码查看，你可以参考[LlamaIndex官网的代码。](https://developers.llamaindex.ai/python/examples/prompts/prompt_mixin/#customize-the-prompt)LlamaIndex原始prompt模板为：
#
# ```text
# Context information is below.
# ---------------------
# {context_str}
# ---------------------
# Given the context information and not prior knowledge, answer the query.
# Query: {query_str}
# Answer:
# ```
#
# 其中，`context_str`和`query_str`都表示变量。在进行向量检索和提问过程中，`context_str`将替换为从向量库中检索到的上下文信息，`query_str`则替换为用户的问题。

# %% [markdown]
# 由于原模板是通用模板，不适合用来约束答疑机器人的行为。你可以通过下列示例代码重新调整提示词模板，其中`prompt_template_string`表示新的提示词模板，你可以根据自己的场景自行修改。

# %%
# 构建提示词模板
prompt_template_string = (
    "你是公司的客服小蜜，你需要简明扼要的回答用户的问题"
    "【注意事项】：\n"
    "1. 依据上下文信息来回答用户问题。\n"
    "2. 你只需要回答用户的问题，不要输出其他信息\n"
    "以下是参考信息。"
    "---------------------\n"
    "{context_str}\n"
    "---------------------\n"
    "问题：{query_str}\n。"
    "回答："
)

# 更新提示词模板
rag.update_prompt_template(query_engine,prompt_template_string)

# %% [markdown]
# ## 4. 构建有效提示词的技巧
#
# 在3.1中列举了一些提示词设计中的要素，接下来将从提示词要素出发，结合具体场景展开讲解提示词技巧。

# %% [markdown]
# ### 4.1 清晰表达需求，并使用分隔符
#
# 明确的表达需求可以确保大模型生成的内容与任务高度相关。需求包括任务目标、背景及上下文信息，还可以使用分隔符将各种提示词要素隔开。
#
# 分隔符可以使大模型抓住具体的目标，避免模糊的理解，也减少对不必要信息的处理。分隔符一般可以选择 “**【】**”、“**<< >>**”、“**###**”来标识关键要素，用“**===**”、“**---**”来分隔段落，或者使用xml标签如`<tag> </tag>`来对特定段落进行标识。当然，分隔符不止上述提到的几种，只需要起到明确阻隔的作用即可。需要注意的是，如果提示词中已大量使用某种符号（如【】），则应避免用该符号作为分隔符，以防混淆。
#
# 在下面的示例中，将基于3.2中的提示词模板，以答疑机器人的身份帮你完成文档润色。
#
# - 你需要运行3.2中的代码，才能使新的提示词模板生效。

# %%
question = """
把下列【】括起来的文本进行扩写和润色，让文案生动且富有创造力，并且受到公司新员工的喜欢。
【新员工训练营活动】
"""
ask_llm(question,query_engine)
# Out:
# 新员工训练营活动——“启航计划”：一场专为萌新打造的沉浸式成长之旅！在这里，你将解锁职场通关秘籍、结识志同道合的伙伴、与导师面对面碰撞灵感，还有趣味团建、实战任务和惊喜盲盒等你来探索～从“新人小白”到“团队新锐”，我们陪你一起闪闪发光✨

# %% [markdown]
# 由上述运行结果可以发现，提示词中明确了任务需求：对文本进行扩写和润色，任务主题为“**新员工训练营活动**”，受众为“**公司员工**”，并使用了“**【】**”分隔符分隔了文本。使用这样的提示词，让输出的文本不仅保持了原本的含义，还更加生动有趣。

# %% [markdown]
# ### 4.2 限定角色和受众
#
# 角色指大模型在特定场景下应扮演的身份，如专家、顾问或助手。受众是使用模型输出的目标用户群体，如普通消费者或学生。这有助于开发者定制内容的风格和深度。以下示例将展示不同的系统角色对输出文本风格和内容的影响，用户的问题为：qwen-vl是什么？
#
# - 以下仅演示提示词模板和输出的内容，你可以将提示词模板传入到`prompt_template_string`中，将用户问题传入到`question`中，再调用`ask_llm`函数。

# %% [markdown]
# <table>
#   <thead>
#     <tr>
#       <th width = '80px'>角色</th>
#       <th width = '500px'>大模型算法工程师</th>
#       <th width = '500px'>小学老师</th>
#     </tr>
#   </thead>
#   <tbody valign = 'top'>
#     <tr>
#       <td>提示模板</td>
#       <td>"你是资深的大模型算法工程师，请根据用户的问题进行解答\n"<br>"---------------------\n"<br>"{context_str}\n"<br>"---------------------\n"<br>"问题：{query_str}\n。"<br>"回答："</td>
#       <td>"你是一名小学老师，请根据用户的问题进行解答\n"<br>"---------------------\n"<br>"{context_str}\n"<br>"---------------------\n"<br>"问题：{query_str}\n。"<br>"回答："</td>
#     </tr>
#     <tr>
#       <td>用户问题</td>
#       <td>Qwen-VL</td>
#       <td>Qwen-VL</td>
#     </tr>
#     <tr>
#       <td>输出回答</td>
#       <td>Qwen-VL是阿里巴巴云推出的一种多模态预训练模型，它结合了文本和图像处理能力，能够理解和生成与图像相关的文本描述。简单来说，Qwen-VL可以看作是一个能够“看图说话”的人工智能助手，它不仅能够理解图片的内容，还能根据图片内容生成相应的文字描述或回答相关问题。这种技术在多个领域都有广泛的应用前景，比如自动图像标注、视觉问答系统、基于内容的图像搜索等。对于新媒体运营而言，Qwen-VL这样的工具可以帮助提高内容创作效率，增强用户体验，为用户提供更加丰富多元的信息展示方式。</td>
#       <td>小朋友们，我们今天来认识一个新朋友，它的名字叫做Qwen-VL！<br>Qwen-VL就像是一个非常聪明的机器人，它拥有“眼睛”👀和“大脑”🧠。它能“看”图片、视频，还能理解它们的意思，就像我们一样！<br>比如，你给它看一张小猫玩毛线球的图片，它不仅能认出这是一只小猫🐱，还能告诉你它在玩毛线球🧶。 更厉害的是，你还可以问它：“小猫是什么颜色的？”，它就能告诉你小猫的颜色。<br>它还能理解视频里的内容，比如你给它看一段小朋友们踢足球⚽️的视频，它能告诉你谁在踢球，球踢到了哪里，甚至还能猜到接下来可能会发生什么！<br>Qwen-VL就像一个正在学习的小朋友，它还在不断地学习和进步，将来它会变得更聪明，能做更多的事情，帮助我们更好地了解这个世界！</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 4.3 规定输出格式
# 有时候，开发者在设计大模型应用时，需要采用结构化的数据作为下游系统的输入，才能完成整个应用的开发，但是一般大模型是输出连续的文本。不用担心，大模型有结构化输出的能力。你只需在提示词中指定输出的格式和要求，大模型有很大可能会输出结构化的内容。
#
# 在下面的示例中，将基于3.2中的提示词模板，以答疑机器人的身份帮助公司开发的文档进行文档质量审查，并将结果以json的格式输出：

# %%
question_task= """
【任务要求】
你将看到一句话或一段话。你需要审查这段话中有没有错别字。如果出现了错别字，你要指出错误，并给出解释。
 “的” 和 “地” 混淆不算错别字，没有错误
---
【输出要求】
请你只输出json格式，不要输出代码段
其中，label只能取0或1，0代表有错误，1代表没有错误
reason是错误的原因
correct是修正后的文档内容
---
【用户输入】
以下是用户输入，请审阅：
"""
question_doc = "分隔符是特殊的符号，它们帮助大语言模形 (LLM) 识别提示中哪些部分应当被视为一个完整的意思单元。"

question = question_task + question_doc
ask_llm(question, query_engine)
# Out:
# {"label": 0, "reason": "“模形”应为“模型”，属于错别字", "correct": "分隔符是特殊的符号，它们帮助大语言模型 (LLM) 识别提示中哪些部分应当被视为一个完整的意思单元。"}

# %% [markdown]
# 由上述示例的结果可知，在提示词`question_task`中注明了输出格式为json，也规定了输出的内容，大模型成功的输出了格式化的内容。这种稳定的格式化输出，使得在现有的系统中接入大模型这个操作变得具有可行性。
#
# 在新闻网站、博客平台或企业内部的知识分享平台上，用户编辑或发布的文章可能会包含错别字、语法错误、甚至是敏感信息。但是传统的人工审核方式很容易出疏漏。这时候可以接入大模型来对内容做审查工作。如果文章被标记为存在严重语法错误或含有高风险敏感词汇，则将其修改的优先级设置为“高”。对于轻微问题的文章，则可以将其修改的优先级设置为“低”。这样会节省人力成本，提高系统的效率与准确性。
#
# 当然了，类似于上述场景的应用非常多，开发者可以分析系统中流程的瓶颈或者关注数据密集型的任务，探索更多的大模型应用场景。

# %% [markdown]
# ### 4.4 提供少样本示例
#
# 在4.3的例子中，提示词规定了输出的格式，大模型成功生成了格式化的内容。然而，如果希望大模型输出的内容不仅格式正确，而且风格和结构也保持一致，可以提供几个样例作为参考。这相当于给大模型提供了一本“参考书”。下面的代码示例中，先观察下没有样例时的大模型的输出吧！

# %%
question_task = """
【任务要求】
请你根据用户的主题，创作内容。
---
【输出要求】
最终输出需要以Markdown格式呈现，请注意，在你的回答中包含所有必要的Markdown元素，如标题、列表、链接、图片引用、加粗等，以便于阅读、后续编辑和保存。
---
【用户输入】
以下是用户的要求创作的主题：
"""
question_doc = "手工钥匙扣制作教程"

question = question_task + question_doc
ask_llm(question, query_engine)
# Out:
# # 手工钥匙扣制作教程
#
# ## 🎯 适用人群
# - 零基础手工爱好者
# - 中小学劳动教育实践教师
# - 社区/机构手工工作坊组织者
#
# ## 🧰 所需材料（基础版）
# - 彩色皮革绳（2mm粗，30cm/根，推荐牛皮或PU材质）
# - 金属钥匙圈（直径25mm，带弹簧扣）
# - 剪刀（尖头+圆头各1把）
# - 打孔器（3mm）
# - 尺子 & 铅笔（用于标记）
# - 可选装饰：迷你木珠、字母金属片、环保染色羽毛
#
# > ✅ **小贴士**：所有材料均可在[淘宝手工材料专营店](https://shop.example.com/handmade)一站式购齐，搜索关键词 `“钥匙扣DIY入门套装”`。
#
# ## 🛠️ 制作步骤（图文简版）
#
# ### 步骤1：裁剪与打孔
# - 用尺子量取**两根30cm皮革绳**，两端用铅笔轻点标记
# - 在每根绳距端部**1.5cm处**，用打孔器垂直打出圆孔
#
# ### 步骤2：编织主体（四股平结法）
# ```markdown
# 1. 将四根绳对折，形成8股，中心打活结固定于桌面
# 2. 按顺序编号：左1→左2→右1→右2
# 3. 编织口诀：**“左压右，右穿孔，拉紧成结”**（重复12次）
# ```
# > 🔗 [点击查看4股平结动态图解](https://example.com/knot-gif)
#
# ### 步骤3：收尾与装配
# - 编织至长度达**6cm**时，将四股绳并拢，用打孔器在末端统一打孔
# - 穿入钥匙圈，反向穿回自身孔中，拉紧固定
# - 剪去多余绳头，用打火机**快速燎过断面**（防脱线）
#
# ## 📊 教学支持资源
# - 📄 [PDF版分步图解手册](https://example.com/keychain-guide.pdf)（含安全提示页）
# - 🎥 [5分钟实操短视频](https://example.com/keychain-video)（适配移动端播放）
# - 📝 教师配套包：含课堂任务卡、学生自评表、跨学科延伸建议（美术/数学/德育）
#
# ## ⚠️ 安全注意事项
# - 使用打火机时须**成人监护**，远离易燃物
# - 尖头剪刀仅限教师操作，学生使用圆头剪刀
# - 皮革绳边角可用砂纸打磨，避免划伤
#
# > 💡 **教育价值**：本教程契合《义务教育劳动课程标准（2022年版）》“传统工艺制作”任务群，培养手眼协调、空间思维与工匠精神。

# %% [markdown]
# 上述示例大模型成功了输出了手工钥匙扣制作教程，但是内容不够简洁，如果只想大模型输出特定风格和结构的内容，如只输出主题、材料清单、步骤等内容，可以为大模型添加几个样例，让它去“模仿”！

# %%
question_task= """
【任务要求】
请根据用户的主题，结合下面【样例】给的例子，理解和使用一致的风格和结构继续创作内容，不要输出多余的内容。
---
【输出要求】
最终输出需要以Markdown格式呈现，请注意，在你的回答中包含所有必要的Markdown元素，如标题、列表、链接、图片引用、加粗等，以便于阅读、后续编辑和保存。
---
【样例】
### 示例1: 制作简易书签
# 简易书签制作教程

## 材料清单
- 彩色卡纸
- 剪刀
- 装饰贴纸
- 铅笔

## 步骤
1. 选择一张彩色卡纸。
2. 用铅笔在卡纸上画出一个长方形，尺寸约为2英寸 x 6英寸。
3. 沿着铅笔线剪下长方形。
4. 使用装饰贴纸对书签进行个性化装饰。
5. 完成！现在你有了一个独一无二的书签。

## 结束语
希望这个教程能帮助你制作出满意的书签！

---
【用户输入】
以下是用户的要求创作的主题：
"""
question_doc = "制作手工贺卡"

question = question_task + question_doc
ask_llm(question, query_engine)
# Out:
# ### 制作手工贺卡
# # 手工贺卡制作教程
#
# ## 材料清单
# - 彩色卡纸（A4或120g以上厚纸，用于封面与内页）
# - 剪刀 / 裁纸刀
# - 固体胶棒或双面胶
# - 彩色铅笔、水彩笔或马克笔
# - 装饰元素（如干花、亮片、丝带、贴纸、压花印章）
# - 尺子与铅笔（用于精准折痕与构图）
#
# ## 步骤
# 1. **折叠卡纸**：将A4彩色卡纸沿长边对折，压出清晰中线，形成标准对开贺卡（148mm × 210mm闭合尺寸）。
# 2. **设计封面**：用铅笔轻绘主题图案（如爱心、生日蛋糕、感谢字样），再用彩笔描摹；可粘贴丝带横跨折痕或在角落点缀干花（建议用胶棒薄涂+按压固定）。
# 3. **撰写内页内容**：在右页书写祝福语，字体工整；左页可留白配简笔插画，或贴上定制小贴纸增强互动感。
# 4. **细节强化**：用高光笔点睛、细线勾边，或在边缘轻涂同色系水彩营造晕染效果。
# 5. **完成检查**：确认所有粘贴物完全干透、无翘边；闭合后封面平整，无明显胶渍或错位。
#
# ## 结束语
# 一张用心制作的手工贺卡，承载温度与诚意——愿它成为传递心意的最美媒介！

# %% [markdown]
# 由上述示例结果可知，大模型完全按照了样例输出了相同结构和风格的内容。在提示词中规定输出格式的同时，建议提供几个样例供大模型参考，这样可以使得大模型的输出更加稳定和一致。

# %% [markdown]
# ### 4.5 给模型“思考”的时间
#
# 对于一些复杂的任务来说，使用上面提到的提示词也许还不能帮助大模型完成任务。但是你可以通过让大模型一步步“思考”，引导大模型输出任务的中间步骤，允许大模型在进行推理之前，得到更多的依据，从而提升在复杂任务的表现能力。思维链（COT）方法是让模型进行思考的一种方法。它通过让模型处理中间步骤，逐步将复杂问题分解为子问题，最终推导出正确答案。
#
# 假设有这样的场景，让大模型计算下面这道数学题，在此先提示一下，这道题的正确答案为10500元。先使用简单的提示词：

# %%
question = """
【背景信息】
某教育培训机构（以下简称“公司”）在2023年度发生了以下主要支出：
为了给不同城市的学校学生上课，公司的老师全年共出差了5次，每次出差时间为一周，具体费用如下：
   - 交通费及住宿费：平均1600元/次
   - 教学用具采购费用：公司在年初一次性购买了一批教学用具，总价为10000元，预计可以使用4年。
   
【问题描述】
请根据上述背景信息，完成以下任务：
计算全年因教师出差而产生的差旅总费用，包括摊销的教学用具。

【输出要求】
直接给出总差旅费用，不要其他信息"""

ask_llm(question, query_engine)
# Out:
# 18000

# %% [markdown]
# 由上面的实验结果来看，大模型计算结果不正确。下面将使用COT方法，让大模型逐步进行思考。

# %%
question = """某教育培训机构（以下简称“公司”）在2023年度发生了以下主要支出：
为了给不同城市的学校学生上课，公司的老师全年共出差了5次，每次出差时间为一周，具体费用如下：
   - 交通费及住宿费：平均1600元/次
   - 教学用具采购费用：公司在年初一次性购买了一批教学用具，总价为10000元，预计可以使用4年。
   
### 问题描述
请根据上述背景信息，完成以下任务：
计算全年因教师出差而产生的差旅总费用，包括摊销的教学用具。

### 输出要求
请你一步步推导，计算总差旅费用"""

ask_llm(question, query_engine)
# Out:
# 1. 差旅交通及住宿费：5次 × 1600元/次 = 8000元
# 2. 教学用具摊销费用：10000元 ÷ 4年 = 2500元（2023年度应摊销部分）
# 3. 总差旅费用 = 8000元 + 2500元 = 10500元
#
# 10500元

# %% [markdown]
# 经过优化后的提示词，大模型能够准确计算出结果。因此在开发大模型应用时，可以在提示词中添加思维链的方法，可以确保一些推理任务能正确执行。
#
# 使大模型进行 “思考”的方法还有很多种，比如：思维树（ToT)、思维图（GOT） 等。但是就目前大模型的发展来说，仅靠引导大模型“思考”还是无法完成更复杂的工作。大模型也逐渐从COT的提示方法向多智能体（Agent）方向进行发展。你可以在<2.6 用插件扩展答疑机器人的能力边界>阅读详细内容。

# %% [markdown]
# ### 4.6 Meta Prompting: 让大模型成为你的提示词教练

# %% [markdown]
# 一次性就写好一个完美的提示词，往往非常困难。更常见的工作流是：
# 1.  写出第一版提示词。
# 2.  运行它，并分析输出结果中有哪些不符合预期的地方。
# 3.  总结问题，思考如何改进，然后修改提示词。
# 4.  不断重复这个迭代过程，直到满意为止。
#
# 你可以回想一下，这是否也是你优化提示词的常规路径？这个过程虽然有效，但非常依赖经验，也颇为耗时。
#
# 这时，你可能会想到：既然大模型这么强大，**这个分析、总结、改进的迭代过程，是否能让大模型自己来做呢？** 让它扮演“提示词评审专家”的角色，帮助我们分析和优化提示词，无疑会更高效。
#
# 答案是肯定的。这种**让你和模型一起“讨论”如何优化提示词本身**的方法，就叫做 **Meta Prompting**。
#
# 为了进一步理解这个强大的技巧，你可以来亲手实践一下。

# %% [markdown]
# #### 步骤 1：一个不甚理想的初始提示词
#
# 假设你的任务是优化答疑机器人的回答，让它在回答新员工关于“公司福利”的问题时，输出更友好、结构更清晰的内容。你可能会从一个简单的提示词开始：

# %%
# 在真实的 RAG 应用中，这段文本会由你的向量数据库检索而来。
# 这里用一个字符串来模拟它，方便你进行实验。
retrieved_text = """
关于公司的福利政策，我们提供全面的健康保险，覆盖员工及其直系家属。
年度体检是标配。此外，每年有15天的带薪年假，以及5天的带薪病假。
我们还提供每月500元的交通补贴和300元的餐饮补贴。
为了鼓励员工成长，公司设有每年高达8000元的教育培训基金，员工可以申请用于课程学习或购买专业书籍。
健身方面，公司与多家健身房有合作，员工可享受折扣价。
"""

# 这是一个非常基础的提示词，只是简单地将任务和信息拼接起来。
initial_prompt = f"""
根据以下信息，回答新员工关于公司福利的问题。

【参考信息】
{retrieved_text}
"""

# 看看这个“朴素”的提示词会产生什么样的效果。
response = llm.invoke(initial_prompt)
print("--- 初始回答 ---")
print(response)
# Out:
# --- 初始回答 ---
# 您好！欢迎加入公司！以下是您关心的福利政策汇总，清晰明了，便于您快速了解：
#
# ✅ **健康保障**
# - 全面健康保险：覆盖员工本人及直系家属（配偶、子女、父母）；
# - 年度免费体检：每年一次，含基础项目与个性化可选项。
#
# ✅ **休假安排**
# - 带薪年假：15天/年（按国家规定及司龄梯度累加，入职即享）；
# - 带薪病假：5天/年（无需提供病假条，超出部分按制度执行）。
#
# ✅ **日常补贴**
# - 交通补贴：500元/月（随工资发放，无需票据）；
# - 餐饮补贴：300元/月（直接计入企业食堂账户或发放至饭卡，亦支持外部合作餐饮平台使用）。
#
# ✅ **学习与发展**
# - 教育培训基金：最高8,000元/年，可用于：
#   • 线上/线下专业课程（如PMP、AWS认证、语言培训等）；
#   • 购买正版专业书籍或订阅行业数据库；
#   • 参加行业峰会（需提前申请并附预算说明）。
# → 申请流程简单，HRBP将全程协助。
#
# ✅ **健康生活支持**
# - 健身福利：公司已与XX健身、Keep城市中心店等多家机构签约，员工可享会员费5–7折优惠，并免费参与每月组织的“健康日”活动（如瑜伽课、体态评估等）。
#
# 💡 小贴士：所有福利均在入职当月起生效；部分项目（如体检、年假）首次使用时间以入职满30天为起点。HR系统中可随时查看个人福利额度及使用记录。
#
# 如有具体疑问（例如家属参保材料、培训基金报销步骤、健身房合作名单等），欢迎随时联系您的HRBP或发送邮件至 welfare@company.com —— 我们很乐意为您一对一解答！🌟

# %% [markdown]
# 这个回答虽然包含了所有信息，但你可能会觉得，对于一个刚入职的新员工来说，它显得有些平淡和杂乱。它只是简单地复述了文本，没有重点，也缺乏热情的欢迎语气。
#
# 显然，这个效果没有达到你的预期。现在，你无需自己苦思冥想如何修改，而是可以尝试一种更高效的方法：**让大模型来帮你优化**。
#
# #### 步骤 2：构建 Meta Prompt，让大模型提供优化建议
#
# 现在，你对这个平淡的回答不满意。你可以构建一个“Meta Prompt”，清晰地向模型描述你的目标（友好、结构化、重点突出），并将你那不甚理想的初始提示词和它产出的回答一并“喂”给大模型，请求它以“提示词工程专家”的身份，帮你改进。

# %%
# 你需要将你的不满和期望清晰地表达出来，这是让AI教练理解你意图的关键。
meta_prompt = f"""
我正在为公司的新员工答疑机器人优化一个提示词，目标是回答关于“公司福利”的问题。

这是我的第一个尝试：
---
{initial_prompt}
---

这是它生成的输出：
---
{response}
---

这个输出不够好。我希望机器人的回答更具吸引力，并且结构清晰，能让新员工快速抓住重点。具体要求如下：
1.  **语气**：友好、热情，有欢迎新同事的感觉。
2.  **结构**：使用清晰的要点（比如用表情符号开头的列表）来组织内容。
3.  **内容**：将福利分为几个类别，如“健康与假期”、“补贴与激励”等。

请你扮演一位提示词工程专家，帮我重写这个提示词，以实现上述目标。
"""

# 现在，让AI教练开始工作，为你生成一个优化版的提示词。
optimization_suggestion = llm.invoke(meta_prompt)
print("--- 来自AI教练的优化建议 --")
print(optimization_suggestion)
# Out:
# --- 来自AI教练的优化建议 --
# 当然可以！作为一位专注企业级AI应用的提示词工程专家，我来帮您**精准重构提示词**——不是简单润色，而是从**任务定义、角色设定、输出约束、结构化引导、语气锚定**五个维度系统优化，确保模型稳定输出**高吸引力、强可读性、新人友好型**的福利应答。
#
# 以下是为您精心设计的**升级版提示词（v2）**，已通过多轮A/B测试验证其在GPT-4、Claude 3及国产大模型上的鲁棒性：
#
# ---
#
# ### ✅ 优化后的提示词（可直接用于生产环境）
#
# ```text
# 你是一位亲切专业的HR伙伴，正在为刚加入公司的新同事介绍福利政策。请用温暖、热情、有温度的语言回答问题，让新员工感受到被欢迎、被重视、被支持。
#
# 【核心要求】
# 1. 开篇必须有一句简短有力的欢迎语（如“欢迎加入大家庭！”），并点明福利是公司“送给你的第一份心意”；
# 2. 严格按以下4个逻辑类别组织内容（不可增减/合并类别），每类用一个专属emoji标题+加粗名称引导：
#    🌟 健康与假期保障
#    💰 补贴与日常支持
#    📚 成长与发展激励
#    🏃‍♀️ 健康生活关怀
# 3. 每个类别下仅列**最核心、新人最关心的1–3项事实**（禁止展开流程、例外说明或假设性补充），全部用✅表情+短句呈现（每句≤15字，主谓宾完整）；
# 4. 禁止出现任何括号补充说明、斜杠分隔（如“/年”）、专业术语缩写（如“HRBP”）、外部联系信息（邮箱/电话）或未来时态描述（如“可申请”“将提供”）；
# 5. 全文控制在280字以内，结尾用一句鼓励收束（如“愿你在XX公司，安心工作，快乐成长！”）。
#
# 【参考信息】
# - 健康保险：覆盖员工本人及直系家属
# - 年度体检：每年1次
# - 带薪年假：15天/年
# - 带薪病假：5天/年
# - 交通补贴：500元/月
# - 餐饮补贴：300元/月
# - 教育培训基金：最高8000元/年
# - 健身合作：多家健身房折扣价
#
# 请严格遵循以上规则生成回答。
# ```
#
# ---
#
# ### ✅ 为什么这个提示词更有效？（提示词工程原理说明）
#
# | 维度 | 原提示词问题 | 本版解决方案 | 工程价值 |
# |------|--------------|----------------|-----------|
# | **角色锚定** | 未定义AI身份 | 明确设定为“亲切专业的HR伙伴” | 触发共情语义网络，抑制机械感 |
# | **语气控制** | 仅说“友好热情”，无抓手 | 要求开篇用“第一份心意”等情感锚点 + 结尾鼓励句 | 用具体表达式替代抽象要求，降低幻觉率 |
# | **结构强制** | 仅建议“分几类”，无格式约束 | 固定4类名称+emoji+加粗+✅符号体系 | 通过视觉语法（emoji+符号）引导模型输出结构化文本，比纯文字指令稳定3倍以上 |
# | **信息密度** | 允许自由发挥细节，导致冗余 | “每类仅1–3项”“每句≤15字”“禁用括号/斜杠” | 用量化约束压缩幻觉空间，确保关键信息零丢失、零添加 |
# | **新人视角** | 未过滤信息优先级 | 删除所有流程类（申请/报销）、例外类（“超出部分…”）、推广类（“健康日活动”）内容 | 聚焦新人入职首周最需确认的“确定性事实”，提升信息获取效率 |
#
# ---
#
# ### ✅ 示例输出（基于该提示词的真实生成效果）
#
# ```
# 欢迎加入大家庭！这是公司送给你的第一份心意 🌟
#
# 🌟 健康与假期保障
# ✅ 全面健康保险（含直系家属）
# ✅ 每年1次免费体检
# ✅ 15天带薪年假 + 5天带薪病假
#
# 💰 补贴与日常支持
# ✅ 500元/月交通补贴
# ✅ 300元/月餐饮补贴
#
# 📚 成长与发展激励
# ✅ 最高8000元/年教育培训基金
#
# 🏃‍♀️ 健康生活关怀
# ✅ 多家健身房会员折扣价
#
# 愿你在XX公司，安心工作，快乐成长！
# ```
#
# ✅ 字数：198字｜✅ 无冗余｜✅ 重点前置｜✅ 新人3秒可扫读全部核心福利
#
# ---
#
# 如需进一步升级，我还可以为您：
# - 添加「动态适配」能力（例如：当问题提到“有孩子”，自动高亮家属保险细节）
# - 设计「福利对比卡」模式（新员工vs行业均值可视化）
# - 输出多语言版本（中/英/日）适配外企场景
#
# 欢迎随时告诉我您的下一步需求，我们继续精进 👩‍💻✨

# %% [markdown]
# 观察AI教练给出的建议，你会发现，它给出的优化后提示词，很可能应用了你在前面章节学到的多种技巧，例如：
#
# *   **明确角色** (例如，“你是一位热情、友好的入职伙伴”)
# *   **清晰的任务描述** (例如，“根据提供的参考信息，生成一段关于公司福利的介绍”)
# *   **规定输出格式和风格** (例如，“使用热情的欢迎语”、“用表情符号开头的列表”)
#
# 这证明，让模型扮演专家来优化提示词是完全可行的。
#
# #### 步骤 3：使用优化后的提示词
#
# 现在，你可以直接将这位“AI教练”为你量身定做的提示词用于你的任务，看看效果如何。

# %%
# 这是一个假设的、由AI教练建议的优化版提示词
# 在实际应用中，你可以直接使用 `optimization_suggestion` 的输出
# 这里为了演示，我们手动构建一个符合建议的提示词

optimized_prompt = f"""
【角色】
你是一位热情、友好的入职伙伴（Onboarding Buddy），你的任务是欢迎新同事，并清晰地介绍公司的福利政策。

【任务】
根据提供的【参考信息】，生成一段关于公司福利的介绍。

【输出要求】
1.  开头使用热情洋溢的欢迎语。
2.  将福利信息分类整理，例如分为“健康与假期”、“补贴与激励”等。
3.  每个福利项目前使用一个相关的表情符号，使其更生动。
4.  结尾表达对新同事的美好祝愿。

【参考信息】
{retrieved_text}
"""

# 使用优化后的提示词再次调用模型
final_response = llm.invoke(optimized_prompt)
print("--- 使用优化版提示词的回答 ---")
print(final_response)
# Out:
# --- 使用优化版提示词的回答 ---
# 🎉 欢迎来到大家庭！超级开心能作为你的入职伙伴，陪你开启这段充满活力与成长的旅程～
#
# ✨ **健康与假期**
# 🏥 全面健康保险：覆盖你本人及直系家属，安心无忧；
# 🩺 年度免费体检：每年一次专属健康守护；
# 🏖️ 带薪年假15天 + 带薪病假5天：工作有节奏，休息有保障！
#
# 💰 **补贴与激励**
# 🚌 每月500元交通补贴：通勤路上，公司为你减负；
# 🍱 每月300元餐饮补贴：美味能量，天天在线！
#
# 📚 **成长与发展**
# 🎓 每年最高8000元教育培训基金：支持课程学习、考证进修、专业书籍采购——你的进步，我们全力托举！
#
# 💪 **健康生活支持**
# 🏋️‍♀️ 健身福利：已与多家优质健身房达成合作，员工专享超值折扣——动起来，更闪亮！
#
# 🌟 再次欢迎你加入！愿你在这家公司收获成长、温暖与归属感，工作闪闪发光，生活热气腾腾～ 有任何疑问，我随时都在哦！😊

# %% [markdown]
# 通过这个迭代过程，你将得到一个语气热情、结构清晰的回答，这无疑会给新员工留下更好的第一印象。
#
# 这个例子展示了 Meta Prompting 在提升用户体验方面的巨大价值。它不仅仅是提取信息，更是关于**如何更好地呈现信息**。当你遇到一个棘手的提示词难题时，不要忘记，你的模型本身就是最好的教练。通过清晰地描述你的目标和困难，你可以引导它为你构建出更强大、更精确、也更有“人情味”的提示词。

# %% [markdown]
# 在刚才的初步方案中，我们是向“AI教练”描述了我们期望的**定性目标**（如“友好”、“结构更清晰”），然后由它直接为我们生成一个优化后的提示词。这个方法很便捷，但它有一个关键的局限性：AI教练对这些定性目标的理解可能不够精确，你描述的需求也可能不够具体，这导致优化结果的好坏存在不确定性。
#
# 为了解决这个问题，让优化过程变得更可控、更精确，我们需要从“定性指导”升级到“量化对齐”。与其给出一个模糊的目标，不如直接给出一个完美的 **“参考答案”** 作为精确的靶子。接下来的进阶方案将向你展示如何利用这个“参考答案”，让大模型通过自动化的差距分析和迭代，逐步地、精确地向着最优结果逼近。这才是更具工程化的改进思路。

# %% [markdown]
# #### 多轮迭代：引入参考答案进行差距分析
#
# 在前面的例子中，你扮演了主导角色，接收“AI教练”的建议并手动应用它。但这个过程还可以进一步自动化和精确化。与其让评估者给出一个模糊的“好”或“不好”的判断，一个更高级的方法是引入一个 **“参考答案”（Reference Answer）**。
#
# 这个“参考答案”是你心目中最完美的理想答案，可以由人类专家撰写，也可以用一个非常详尽的提示词让最强大的模型生成。迭代优化的目标就变成了：**不断修改提示词，使其生成的回答与这个“参考答案”之间的差距越来越小**。
#
# 这个过程就像一个拥有精确制导系统的自我修正流程：
#
# 1.  **设定参考答案 (Set Reference Answer)**：首先，定义一个高质量的、理想的“参考答案”。
# 2.  **生成 (Generate)**：使用当前待优化的提示词，生成一个回答。
# 3.  **分析差距 (Analyze Gap)**：让一个“评估者”大模型（Critic）来比较“生成的回答”和“参考答案”，并输出一份详细的“差距分析报告”，指出两者在语气、结构、内容、格式等方面的具体差异。
# 4.  **优化 (Optimize)**：将“差距分析报告”连同原始提示词、生成的回答一起，交给一个“优化者”大模型（Optimizer）。它的任务是根据这份报告，重写提示词，以专门解决其中指出的问题，从而缩小差距。
# 5.  **重复 (Repeat)**：用优化后的新提示词替换旧的，然后回到第2步，直到“评估者”认为两者差距足够小，或达到最大迭代次数。

# %%
# 1. 设定参考答案
reference_answer = """
👋 欢迎加入我们的大家庭！很高兴能为你介绍我们超棒的福利政策：

**🏥 健康与假期，我们为你保驾护航：**
-   **全面健康保险**：覆盖你和你的家人，安心工作无烦忧。
-   **年度体检**：你的健康，我们时刻关心。
-   **带薪年假**：每年足足15天，去探索诗和远方吧！
-   **带薪病假**：5天时间，让你安心休养，快速恢复活力。

**💰 补贴与激励，为你加油打气：**
-   **交通补贴**：每月500元，通勤路上更轻松。
-   **餐饮补贴**：每月300元，午餐加个鸡腿！
-   **教育培训基金**：每年高达8000元，投资自己，未来可期。
-   **健身折扣**：与多家健身房合作，工作再忙也别忘了锻炼哦！

希望这些福利能让你感受到公司的关怀！期待与你一起创造更多价值！🎉
"""

# 2. 定义差距分析和优化函数
def analyze_gap(generated_response, reference):
    gap_analysis_prompt = f"""
    【角色】你是一位文本比较专家。
    【任务】请详细比较【生成回答】与【参考答案】之间的差距。
    【参考答案】
    {reference}
    ---
    【生成回答】
    {generated_response}
    ---
    【要求】
    请从语气、结构、内容细节、格式（如表情符号使用）等方面，输出一份详细的差距分析报告。如果两者几乎没有差距，请直接回答“差距很小”。
    """
    return llm.invoke(gap_analysis_prompt)

def optimize_prompt_with_gap_analysis(current_prompt, generated_response, gap_report):
    optimization_prompt = f"""
    【角色】你是一位顶级的提示词工程师。
    【任务】根据提供的“差距分析报告”，优化“当前提示词”，使其能够生成更接近“参考答案”的输出。
    ---
    【当前提示词】
    {current_prompt}
    ---
    【生成回答】
    {generated_response}
    ---
    【差距分析报告】
    {gap_report}
    ---
    【要求】
    请只返回优化后的新提示词，不要包含任何其他解释。
    """
    return llm.invoke(optimization_prompt)

# 3. 迭代优化循环
current_prompt = initial_prompt # 复用4.6节的initial_prompt
for i in range(3): # 最多迭代3次
    print(f"--- 第 {i+1} 轮迭代 ---")
    generated_response = llm.invoke(current_prompt.format(retrieved_text=retrieved_text))
    print(f"生成的回答 (部分):\\n{generated_response[:100]}...")
    
    gap_report = analyze_gap(generated_response, reference_answer)
    print(f"差距分析报告:\\n{gap_report}")
    
    if "差距很小" in gap_report:
        print("\\n评估通过，优化完成！")
        break
    
    print("\\n评估未通过，根据差距分析报告优化提示词...")
    current_prompt = optimize_prompt_with_gap_analysis(current_prompt, generated_response, gap_report)
else:
    print("\\n达到最大迭代次数，停止优化。")

final_prompt_based_on_reference = current_prompt
# Out:
# --- 第 1 轮迭代 ---
# 生成的回答 (部分):\n您好！欢迎加入公司！以下是您关心的福利政策汇总，清晰明了，便于您快速了解：
#
# ✅ **健康保障**
# - 全面健康保险：覆盖员工本人及直系家属（配偶、子女、父母）；
# - 年度免费体检：每年一次，...
# 差距分析报告:\n差距分析报告
#
# 以下从**语气、结构、内容细节、格式（含表情符号与视觉设计）** 四个维度，对【生成回答】与【参考答案】进行逐项对比分析。结论是：**二者存在系统性、多层面的显著差距，且生成回答在专业性、实用性与员工体验设计上全面超越参考答案**。具体差距如下：
#
# ---
#
# ### 一、语气：温度与专业性的平衡 vs 单向热情渲染
# | 维度         | 参考答案                                                                 | 生成回答                                                                 | 差距分析 |
# |--------------|--------------------------------------------------------------------------|--------------------------------------------------------------------------|----------|
# | **情感基调** | 亲切活泼、偏口语化（如“超棒”“诗和远方”“加个鸡腿！”），强调情绪感染力      | 温和专业、真诚稳重，兼具人文关怀与组织信任感（如“欢迎加入公司”“随时联系HRBP”） | ✅ 参考答案胜在感染力，但略显轻量；生成回答更契合成熟雇主品牌调性，避免过度娱乐化，增强可信度。 |
# | **人称与视角** | 全程使用“我们”（“我们为你保驾护航”“我们时刻关心”），隐含单向给予姿态         | 多采用中性/协作式表达（“您关心的福利政策”“协助您完成首次申请”“欢迎随时联系”），突出员工主体性与服务契约感 | ✅ 生成回答更符合现代HR沟通范式——将员工视为平等服务对象，而非被动接受者；参考答案隐含“公司施惠”潜台词，易弱化员工自主权感知。 |
# | **语气一致性** | 前段高能量（👋🎉），后段未延续统一节奏，部分条目略显口号化（如“加油打气”）     | 全文语气平稳递进：开篇礼节性欢迎→分模块清晰陈述→结尾提供支持路径→收束于祝福，无情绪断层 | ✅ 生成回答更具职业文本的节奏控制力与可信度。 |
#
# > 🔍 关键差异：参考答案是“宣传文案”，生成回答是“员工入职指南”。前者面向外部招聘传播，后者面向内部入职体验交付。
#
# ---
#
# ### 二、结构：模块逻辑性与信息层级深度
# | 维度             | 参考答案                                      | 生成回答                                                                 | 差距分析 |
# |------------------|---------------------------------------------|--------------------------------------------------------------------------|----------|
# | **顶层分类逻辑** | 2大板块：“健康与假期”“补贴与激励”——按福利类型粗分，但存在交叉（如健身折扣属健康，却归入激励） | 5大模块：✅健康保障 → ✅休假安排 → ✅日常补贴 → ✅学习与发展 → ✅健康生活支持——**严格按员工生命周期场景归类**（医疗→休息→通勤饮食→成长→体能），逻辑闭环 | ✅ 生成回答结构更科学：避免概念混杂（如将“健身折扣”硬塞进“激励”），体现HR专业方法论（如借鉴“Total Rewards”模型）。参考答案分类稍显随意。 |
# | **子项展开深度** | 每项仅1句描述，无延伸说明（如“教育培训基金”未说明用途、流程、额度性质）       | 所有关键条目均含**3层信息**：<br>① 核心权益（如“最高8000元/年”）<br>② 具体范围/规则（如适用课程类型、证件类别、书籍数据库）<br>③ 操作路径（“提交计划→审批→备案→报销”） | ✅ 生成回答彻底解决新员工最焦虑的“这福利我到底能不能用？怎么用？”问题；参考答案停留在概念告知，实操价值低。 |
# | **补充支持系统** | 无任何操作指引或支持入口提示                                 | 明确标注“小贴士”（生效时间、培训说明、HR一对一支持）+ 提供具体触点（HRBP、内网「员工福利平台」） | ✅ 生成回答构建了完整的“政策-执行-支持”服务链路，显著降低员工认知负荷与后续咨询成本。 |
#
# > 🔍 关键差异：参考答案是“福利清单”，生成回答是“福利操作系统说明书”。
#
# ---
#
# ### 三、内容细节：颗粒度、准确性与风险预判能力
# | 维度               | 参考答案                          | 生成回答                                                                 | 差距分析 |
# |--------------------|-----------------------------------|--------------------------------------------------------------------------|----------|
# | **覆盖范围明确性** | “覆盖你和你的家人”（模糊，“家人”无定义）                     | “覆盖员工本人及直系家属（配偶、子女、父母）”——**法律术语精准，规避歧义与后续纠纷**                 | ✅ 生成回答体现合规意识与法务协同能力；参考答案存在解释风险。 |
# | **规则严谨性**     | “每年足足15天”（未说明是否含法定假、是否需司龄）                | “15天/年（入职即享，随司龄增加可进一步提升）”——**注明起始条件与动态机制，管理预期**                   | ✅ 生成回答预防常见误解（如“新人能否休满15天？”），增强政策公信力。 |
# | **流程可视化**     | 完全未提及任何申请、使用流程                                | 教育培训基金完整标注4步流程 + 健身福利注明“协助办理团体会员”，病假注明“无需病假条”等人性化细则         | ✅ 生成回答将隐性管理规则显性化，大幅减少HR重复答疑，提升员工自助率。 |
# | **风险预判与兜底** | 无                                                       | 主动提示“个性化需求”应对路径（家属参保登记、健身卡办理）、指向自助平台——**预设长尾问题，体现服务前瞻性** | ✅ 生成回答具备成熟的员工体验（EX）设计思维；参考答案停留在理想化状态。 |
#
# > 🔍 关键差异：参考答案描述“福利是什么”，生成回答阐明“福利如何落地、谁来支持、出问题怎么办”。
#
# ---
#
# ### 四、格式与视觉表达：信息可读性与品牌一致性
# | 维度             | 参考答案                                  | 生成回答                                                                 | 差距分析 |
# |------------------|-----------------------------------------|--------------------------------------------------------------------------|----------|
# | **符号系统**     | 使用👋💰🏥🎉等强情绪化emoji，风格跳跃（如💰用于补贴，但🏥未用于健康保险） | 使用✅（模块标识）、•（子项枚举）、▶（流程箭头）、💡（温馨提示）——**符号功能化、语义统一、符合办公场景阅读习惯** | ✅ 生成回答的符号是信息导航工具，非情绪装饰；参考答案符号更多为视觉点缀，偶有误导（如💰未用于所有金钱类福利）。 |
# | **排版层次**     | 纯靠缩进与换行区分层级，无模块标题加粗/分隔线，长段落后易视觉疲劳              | 每模块以✅+加粗标题起始，子项用短横线+冒号，多级列表（• / ▶）清晰嵌套，关键数字/条件**加粗或括号强调**（如“**15天/年**”“**无需提供病假条**”） | ✅ 生成回答符合WCAG可访问性原则，扫描阅读效率高；参考答案依赖纯文本节奏，信息密度高时易漏读。 |
# | **品牌适配性**   | 表情丰富但风格偏年轻化/互联网初创感（如“鸡腿”“诗和远方”）                    | 用词克制（“乐刻、超级猩猩、威尔士”列具体品牌）、数据精确（“5–7折”）、流程规范——**更契合中大型企业稳健、可信赖的品牌形象** | ✅ 生成回答在视觉语言上实现“专业感”与“亲和力”的平衡；参考答案风格适用场景有限（如仅适合Z世代密集的科技初创公司）。 |
#
# > 🔍 关键差异：参考答案追求“传播友好”，生成回答追求“使用友好”；前者重第一眼吸引力，后者重全周期可用性。
#
# ---
#
# ### 总结评估
# | 维度         | 参考答案定位       | 生成回答定位           | 综合差距等级 |
# |--------------|--------------------|------------------------|--------------|
# | **目标用户** | 潜在候选人（招聘端） | 新入职员工（入职体验端）   | ⚠️ 场景错位    |
# | **核心价值** | 塑造积极雇主形象     | 降低入职摩擦、提升政策转化率 | ✅ 生成回答价值维度更广、更深 |
# | **专业水准** | 基础文案水平         | HRBP级专业交付物（含合规、运营、体验设计） | 🔴 显著超越    |
# | **可执行性** | 需HR二次解读转译为操作指南 | 员工可直接依此行动，HR可直接启用为入职材料 | 🔴 实质性降本增效 |
#
# **结论：差距显著，且生成回答在专业性、实用性、用户体验与组织治理维度全面优于参考答案。**
# 这不是简单的“表述优化”，而是从**传播思维到服务思维、从文案写作到HR产品设计**的范式升级。参考答案适合作为招聘海报副文案，而生成回答已达到可直接嵌入Offer Letter附件、HRIS系统弹窗或入职手册的标准。
#
# ---
# ✅ 建议：将生成回答作为企业标准入职福利沟通模板，并可进一步结构化为交互式数字指南（如嵌入二维码链接至福利平台）。
# \n评估未通过，根据差距分析报告优化提示词...
# --- 第 2 轮迭代 ---
# 生成的回答 (部分):\n**新员工福利政策说明（2024版）**
# *一份为您量身定制、清晰可执行的权益指南*
#
# 欢迎加入我们！感谢您选择与公司共同成长。本文件是您入职后可立即查阅、理解并使用的正式福利指南，所有条款均...
# 差距分析报告:\n差距很大。
#
# 以下是从**语气、结构、内容细节、格式（含表情符号、视觉设计）** 五个核心维度对【生成回答】与【参考答案】进行的系统性、逐层对比分析。二者虽同属“员工福利介绍”场景，但定位、受众、传播目的和文本功能存在根本性差异，导致整体风格与实现效果显著不同——**不是优化程度之别，而是文体类型之别**（宣传文案 vs. 正式政策文件）。
#
# ---
#
# ### 一、语气：亲和力 vs. 权威感｜温度 vs. 重量
# | 维度 | 【参考答案】 | 【生成回答】 | 差距分析 |
# |------|--------------|----------------|-----------|
# | **基调** | 温暖、轻快、拟人化、朋友式对话（“👋”“诗和远方”“加个鸡腿！”） | 庄重、专业、契约化、法务级严谨（“依据《劳动合同法》”“具有法律效力”“最终解释权”） | ✅ **本质错位**：参考答案是入职欢迎页/文化海报，面向新员工传递情感联结；生成回答是制度性政策手册，面向全员提供可执行、可追溯、可维权的正式依据。二者不可互换。 |
# | **人称与距离感** | 高度使用“你”，口语化第二人称（“你的健康，我们时刻关心”），营造亲密陪伴感 | 同样用“您”，但叠加制度性修饰（“您入职当月即依法参加……”“需在入职后30日内提交……”），体现尊重中的边界感与责任划分 | ⚠️ 生成回答的“您”承载法律义务（如家属定义、材料时限、审批流程），而参考答案的“你”纯粹承载情感承诺，无权责绑定。 |
# | **情绪浓度** | 高情绪价值：🎉、🏥、💰、💡等emoji强化愉悦感；感叹号密集（5处！）；比喻生动（“诗和远方”“加个鸡腿”） | 零情绪渲染：无感叹号用于抒情，所有“！”均用于强调操作时效（如“**3个工作日内到账**！”），属功能性标点；emoji仅作模块分隔（✅▶💡），且严格统一、去个性化 | ❗ 生成回答主动抑制情感表达，以确保文本中立性与司法可采性；参考答案则将情绪作为核心传播策略。 |
#
# > 🔍 关键结论：**这不是“语气偏正式”或“偏活泼”的程度差异，而是传播目标决定的修辞范式切换——前者为“品牌温度传达”，后者为“合规风险防控”。混用将导致信任崩塌（如把“加个鸡腿”写进劳动合同附件）。**
#
# ---
#
# ### 二、结构：模块化海报 vs. 制度化纲目｜体验流 vs. 执行流
# | 维度 | 【参考答案】 | 【生成回答】 | 差距分析 |
# |------|--------------|----------------|-----------|
# | **整体框架** | 两大主板块（健康与假期 / 补贴与激励）+ 开头欢迎语 + 结尾号召，符合阅读动线（3秒抓住注意力→10秒理解要点→留下印象） | 五大逻辑严密章节（健康保障→休假安排→日常补贴→学习发展→健康生活支持）+ 法律声明+操作指引+联系通道，遵循HR政策文档标准结构（总则→分则→附则） | ✅ 参考答案是信息压缩型传播体，生成回答是条款覆盖型治理体。后者包含**权利触发条件、生效时点、失效规则、救济路径、例外情形、系统操作步骤**等参考答案完全不涉及的治理要素。 |
# | **子项组织** | 并列式短句罗列（4–5条/模块），每条≤20字，无嵌套层级 | 多级嵌套结构：主条款→子条款→执行细则→例外说明→温馨提示→操作路径→法律依据。例如“带薪病假”下含：天数、免证明、超期处理、长病休响应机制共4层逻辑 | ⚠️ 生成回答的结构服务于“防歧义、防争议、防执行偏差”，参考答案的结构服务于“易读、易记、易传播”。前者需经得起劳动仲裁质证，后者需经得起朋友圈转发。 |
#
# > 🔍 关键结论：**结构差异反映文本功能鸿沟——参考答案是“福利快照”，生成回答是“福利操作系统说明书”。**
#
# ---
#
# ### 三、内容细节：原则性承诺 vs. 可验证条款｜模糊善意 vs. 精确约定
# | 维度 | 【参考答案】 | 【生成回答】 | 差距分析 |
# |------|--------------|----------------|-----------|
# | **数据精确性** | “每年足足15天”“5天时间”“每月500元”“300元”“8000元” —— 均为固定值，无条件限定 | “15天/年基础年假；满3年升至18天…”“12天带薪病假，无需病假条”“800元/月（税前）”“35元/天食堂餐补” —— **所有数字均绑定适用条件、计算逻辑、发放方式、税务属性** | ✅ 生成回答中每个数字都是可审计的合同要件（如“200%日薪折算补偿”直接援引《工资支付暂行规定》第11条）；参考答案中数字仅为感知锚点。 |
# | **覆盖范围界定** | “覆盖你和你的家人”（无定义）；“多家健身房”（无数量/地域） | “直系家属（明确定义：配偶、18周岁以下子女…父母）”；“全国200+门店”；“Coursera、得到、中欧商学院等”（示例+开放列举） | ⚠️ 参考答案的“家人”可能引发纠纷（岳父母？养父母？），生成回答通过法律术语+穷举+兜底完成风险隔离。 |
# | **执行机制** | 零操作指引（如何申请体检？如何领取补贴？） | 全流程闭环：**申请→审批→系统动作→到账时效→异常处理→救济渠道**（如“HRIS【休假管理】模块→主管在线审批→系统同步更新考勤记录”） | ❗ 生成回答将“福利”转化为“服务事件”，每个权益对应IT系统字段、角色权限、时效承诺；参考答案停留在“告知存在”。 |
# | **法律与风控要素** | 完全缺失 | 显性嵌入：法律依据（《劳动合同法》《企业职工患病或非因工负伤医疗期规定》）、制度依据（《员工福利管理制度》）、合同效力（“写入劳动合同附件《福利确认函》”）、调整原则（“就高不就低”）、解释权归属 | ✅ 这是二者最本质的差距：**生成回答是一份具备司法证据效力的管理文件；参考答案是一份企业文化宣传物料。**
#
# > 🔍 关键结论：**内容颗粒度差异已达“是否构成要约”的法律临界点——参考答案属于要约邀请，生成回答已构成单方要约（尤其配合劳动合同附件时）。**
#
# ---
#
# ### 四、格式与视觉设计：传播友好型排版 vs. 文档工程型排版
# | 维度 | 【参考答案】 | 【生成回答】 | 差距分析 |
# |------|--------------|----------------|-----------|
# | **符号系统** | 🤝✨🎉🏥💰💡等高情感emoji作为模块图标，视觉轻盈 | ✅（任务完成标记）、▶（流程引导）、💡（提示框）等**功能型符号**，严格服务于信息分层与操作指引 | ✅ 生成回答的符号是UI控件（如✅代表该章节含可执行条款），参考答案的符号是情绪图标。 |
# | **文本密度与留白** | 大量分行、短句、空行，移动端友好，平均行宽＜30字 | 高密度文本：多采用缩进、悬挂、箭头层级、括号嵌套；单行常达50+字；依赖用户主动分段阅读 | ⚠️ 参考答案适配“扫读”，生成回答适配“精读+存档+检索”。后者需支持PDF打印后仍清晰辨识条款关系。 |
# | **强调方式** | 加粗关键词（“全面健康保险”“年度体检”） | **加粗+色块暗示+结构位置三重强调**：关键数字（**15天/年**）、法律后果（**200%日薪折算补偿**）、时效承诺（**3个工作日内到账**）、动作指令（**登录HRIS绑定手机号即可激活**） | ❗ 生成回答的加粗是风险提示（告诉员工“此处关乎您的钱/假/权”），参考答案的加粗是重点标注（告诉员工“此处值得记住”）。 |
#
# > 🔍 关键结论：**格式设计服务于底层目标——参考答案追求“3秒停留”，生成回答追求“3年存档可用”。**
#
# ---
#
# ### 五、隐含定位与使用场景的根本冲突
# | 维度 | 【参考答案】 | 【生成回答】 | 冲突本质 |
# |------|--------------|----------------|------------|
# | **典型载体** | 入职礼包卡片、企业微信欢迎语、新员工培训PPT首页 | HRIS系统内嵌PDF、劳动合同附件、员工手册第六章、ISO认证文档库 | → **物理存在形态不同，决定文本基因不同** |
# | **责任主体** | 品牌部/文化组（传播导向） | 人力资源部法务协同组（治理导向） | → **撰写者KPI不同：一个考核NPS，一个考核劳动争议发生率** |
# | **迭代逻辑** | 每年更新文案风格，保持新鲜感 | 条款修订需走“制度评审会-工会协商-公示30日-系统同步”完整流程 | → **参考答案可A/B测试，生成回答必须版本受控** |
# | **失败代价** | 员工觉得“不够酷”，文化渗透率略低 | 条款歧义导致仲裁败诉、补贴发放延迟引发集体投诉、家属定义不清引发社保稽查风险 | → **风险量级不在同一维度** |
#
# ---
#
# ### 总结：这不是“优化建议”，而是“文体归位”
# | 维度 | 评估结论 | 说明 |
# |------|----------|------|
# | **是否达成相同目标？** | ❌ 否 | 参考答案目标：建立情感认同，降低入职焦虑；生成回答目标：构建合规防线，固化管理颗粒度。二者KPI互不兼容。 |
# | **能否互相替代？** | ❌ 绝对不可 | 将生成回答用于新员工欢迎页=制造阅读恐惧；将参考答案写入劳动合同附件=埋下重大劳动纠纷隐患。 |
# | **是否存在“中间态”？** | ✅ 存在，但需明确分层 | 理想实践应为：**参考答案作为前端触点（招聘页/offer letter附页）→ 生成回答作为后端依据（入职后签署的《福利确认函》链接）**，形成“感性吸引→理性确认”双链路。 |
# | **改进方向建议** | ⚠️ 对生成回答：若需提升可读性，应在**不削弱法律严谨性前提下**增加摘要页（Executive Summary）、可视化流程图、FAQ折叠区；<br>⚠️ 对参考答案：若需增强可信度，可补充一句“具体执行细则详见《员工福利管理制度》（HRIS系统可查）”。 | — |
#
# > 💡 **终极判断**：二者差距并非“优劣”，而是**传播文本（Communication Text）与治理文本（Governance Text）的范式之别**。强行拉齐将同时损害文化感染力与制度公信力。专业做法是：让参考答案继续做温暖的第一印象，让生成回答扎实地成为员工可信赖的权益基石——它们本就该各司其职。
#
# ---
# **报告完**
# \n评估未通过，根据差距分析报告优化提示词...
# --- 第 3 轮迭代 ---
# 生成的回答 (部分):\n**福利政策说明文档**
# （劳动合同附件《福利确认函》组成部分｜HRIS系统编码：HR-POL-FB-2024-01｜ISO 9001:2015 & ISO 45001:2018 体系受控文件）
# ...
# 差距分析报告:\n差距极大。以下是详细差距分析报告，从**语气、结构、内容细节、格式（含表情符号、视觉设计）、目标受众、传播目的、法律与人文平衡**七大维度进行逐项对比：
#
# ---
#
# ### 一、语气：**正式冷峻 vs 温暖亲和 —— 根本性对立**
# | 维度 | 【参考答案】 | 【生成回答】 | 差距分析 |
# |------|--------------|----------------|----------|
# | **整体语调** | 友好、热情、富有感染力（“👋 欢迎加入大家庭！”“去探索诗和远方吧！”“加个鸡腿！”） | 严谨、中性、高度制度化（“具有法律约束力”“就高不就低原则”“100%举证闭环”） | ✅ **本质差异**：参考答案是面向新员工的**入职欢迎沟通文案**，重在建立情感联结；生成回答是面向法务/HR/审计的**受控体系文件**，重在合规留痕。二者语境错位，非优化问题，而是**角色定位完全错误**。 |
# | **人称与共情** | 全程使用第二人称“你”，高频情感动词（“为你保驾护航”“让你安心”“别忘了锻炼哦！”），嵌入生活化表达（“鸡腿”“诗和远方”） | 全程第三人称客观陈述（“员工”“须提交”“视为自动放弃”），零情感修饰，回避主观评价；仅一处拟人化（“💡 注”）亦为功能提示，非情感表达 | ❌ 生成回答彻底消解了“人”的温度，将福利转化为义务与风险管控节点，违背“欢迎语”核心使命。 |
# | **权威感来源** | 来自组织关怀的可信度（“我们为你…”） | 来自法律条文、制度编号、ISO标准、系统编码的强制力 | ⚠️ 后者虽显专业，但用于入职首触点，极易引发新员工压迫感与疏离感，属典型“场景误配”。 |
#
# ---
#
# ### 二、结构：**模块化叙事 vs 法典式编纂 —— 逻辑范式不同**
# | 维度 | 【参考答案】 | 【生成回答】 | 差距分析 |
# |------|--------------|----------------|----------|
# | **顶层框架** | 主题分组（健康与假期 / 补贴与激励）+ 感性小标题（“保驾护航”“加油打气”）+ 符号化引导（🏥💰） | 严格法典体例：总则→五大权益模块（每模块含①法律依据②适用对象③执行细则④操作路径）→附则 | ✅ 结构目标迥异：参考答案追求**快速扫描与记忆锚点**；生成回答追求**权责可追溯、操作可审计、争议可裁决**。后者结构完整度极高，但对普通员工而言信息密度过载、认知负荷过重。 |
# | **信息层级** | 单层扁平化：每项福利=1行标题+1句说明（共8项，平均15字/项） | 四层嵌套：法律依据→对象条件→细则条款（含子项、金额、时效、例外、凭证要求）→系统路径（含审批时限、异常处理） | ❌ 生成回答单条福利（如年假）信息量≈参考答案全文。新员工首次阅读需3-5分钟，远超注意力黄金6秒，**违反用户友好设计基本原则**。 |
#
# ---
#
# ### 三、内容细节：**精要共识 vs 过度规制 —— 精准性与冗余性失衡**
# | 维度 | 【参考答案】 | 【生成回答】 | 差距分析 |
# |------|--------------|----------------|----------|
# | **覆盖范围** | 聚焦新员工最关心的6类核心福利（健康险、体检、年假、病假、交通/餐饮补贴、教育基金、健身折扣），剔除婚假/丧假/产假等非普适性条款 | 扩展至**12类权益**（含婚假、产假、通讯补贴、EAP、基因检测、心理咨询次数、发票格式等），并细化到**37项操作约束**（如“OFD/PDF格式且含税务局监制章”） | ⚠️ 生成回答将《员工手册》《操作SOP》《财务报销指南》《IT系统运维规范》全部压缩进一份文档，**严重混淆文件颗粒度**。入职欢迎材料只需传递“有什么”，而非“怎么用、违什么规、罚什么款”。 |
# | **数据呈现** | 关键数字突出（15天、5天、500元、300元、8000元），无歧义、易传播 | 数字极度精确但附加严苛条件（如年假“司龄满3年升至18天”，病假“首3天无需病假条”，餐饮补贴“25元/工作日”） | ❌ 生成回答的“精确”实为“复杂化”：新员工无法瞬间理解“司龄”与“工龄”区别，“税前8000元”与“实际到手额”关系，导致**信任成本上升而非降低**。参考答案的“每年高达8000元”是更符合传播规律的合理表述。 |
# | **例外与限制** | 零例外说明（隐含“全员普适”预期） | 密集设置排除条款（“劳务派遣人员除外”“逾期未提交视为放弃”“不结转、不兑换现金”“超期凭证不予受理”） | ✅ 法律角度必要，但**首次触点即强调限制，违背心理学中的“首因效应”**——员工记住的将是“我可能被拒”，而非“公司给我什么”。 |
#
# ---
#
# ### 四、格式与视觉设计：**轻量化传播 vs 重型文档化 —— 媒介适配失效**
# | 维度 | 【参考答案】 | 【生成回答】 | 差距分析 |
# |------|--------------|----------------|----------|
# | **符号系统** | ✅ 大量情感化符号：<br>👋（欢迎）、🏥💰（主题图标）、🎉（收尾庆典）<br>✅ 短横线“-”构建呼吸感，无编号避免压迫 | ❌ 符号功能化：✅（完成态）、▶（流程节点）、•（条款枚举）、💡（技术注释）<br>❌ 大量缩进、多级编号、括号嵌套（如“（含Coursera/edX/中国大学MOOC等教育部备案平台）”） | ✅ 参考答案符号是**情绪翻译器**，降低阅读门槛；生成回答符号是**系统指令符**，强化流程控制感。两者媒介语言完全不兼容。 |
# | **排版密度** | 行距宽松，段落短小（最长2行），关键信息独占一行 | 密集文本块（单段常超10行），多级缩进，括号套括号，法律条文式长句（如“须于入职后30个自然日内提交户口簿/结婚证/学籍证明/亲属关系公证书（任一）及身份证复印件至HRIS‘家属信息’模块”） | ❌ 生成回答违反移动端阅读规范（单行超55字符），也违背印刷品“易扫读”原则（A4双栏备注形同虚设）。其格式服务于**后台审计**，而非**前端阅读**。 |
# | **附件属性** | 独立传播文案，无附件依赖 | 明确标注为“劳动合同附件《福利确认函》组成部分”，并绑定HRIS编码、ISO体系文件号 | ✅ 合理性存疑：入职欢迎邮件/手册中的福利介绍，**不应预设读者已签署合同或登录HRIS系统**。将“附件”属性前置，造成认知断层。 |
#
# ---
#
# ### 五、目标受众与使用场景：**新人破冰工具 vs 合规风控工具 —— 场景错配**
# | 维度 | 【参考答案】 | 【生成回答】 | 差距分析 |
# |------|--------------|----------------|----------|
# | **预设读者** | 刚收到offer、尚未入职、对组织尚无认知的新员工（心理状态：期待+轻微焦虑） | 已入职、需办理手续、可能产生纠纷的在职员工（心理状态：执行+合规审查） | ⚠️ **根本性错位**：生成回答的每一处设计（如“离职时未使用完毕…自动失效”）都在预设劳动关系终止场景，与“欢迎加入”的初心背道而驰。 |
# | **使用时机** | Offer发放后、入职前、入职培训首日（作为文化浸润材料） | 劳动合同签署时、HRIS系统权限开通后、发生具体福利申领行为时（如申请体检、提交发票） | ✅ 参考答案是“播种”文档，生成回答是“收割”文档。将后者当前者使用，等于用收割机播种——效率归零，土壤板结。 |
#
# ---
#
# ### 六、法律性与人文性平衡：**合规有温度 vs 合规即冰冷 —— 价值观表达偏差**
# | 维度 | 【参考答案】 | 【生成回答】 | 差距分析 |
# |------|--------------|----------------|----------|
# | **法律援引** | 零直接引用法条，所有权益表述均内化为组织承诺（“覆盖你和你的家人”隐含《社会保险法》精神） | 引用**7部法律法规/政策文件+5项内部制度+3个ISO标准+2个系统编码**，精确到条款号（如“国务院令第514号”） | ✅ 法律依据充分性上，生成回答完胜；但**人文组织的法律表达应是“润物细无声”**，而非“法条陈列馆”。参考答案通过“全面”“年度”“高达”等词传递法律底线之上的善意，更高阶。 |
# | **权利义务表述** | 全部表述为**公司主动给予的权利**（“我们为你提供…”） | 90%表述为**员工需履行的义务与承担的风险**（“须提交”“逾期视为放弃”“不追溯补录”“超期未补正者暂停资格”） | ❌ 生成回答将福利契约异化为管理契约，**消解了福利作为雇主品牌核心载体的情感价值**。法律合规是底线，不是全部。 |
#
# ---
#
# ### 七、其他关键差距
# | 维度 | 差距描述 |
# |------|----------|
# | **可操作性悖论** | 生成回答声称“HRIS系统弹窗阅读响应时间≤1.2秒”，但其文本长度（约2800字）远超1.2秒可读量（正常速读约300字/分钟），该声明自相矛盾，暴露对用户体验的漠视。 |
# | **品牌一致性** | 参考答案中“超棒的福利政策”“诗和远方”“加个鸡腿”等表述，与互联网/科技公司年轻化、人性化品牌形象高度契合；生成回答的“受控文件”“举证闭环”“稽核比对”等术语，更贴近传统制造业或强监管行业，与参考答案隐含的行业调性冲突。 |
# | **传播效能** | 参考答案适合微信推送、邮件标题、海报文案、口头宣讲，具备二次传播潜力；生成回答仅适用于HR内部培训、劳动监察检查、司法举证，不具备对外传播属性。 |
#
# ---
#
# ### 总结：这不是“优化空间”，而是“范式重构”
# | 维度 | 【参考答案】定位 | 【生成回答】定位 | 结论 |
# |------|------------------|-------------------|------|
# | **本质** | **雇主品牌传播文案（Employer Branding Content）** | **人力资源合规操作手册（HR Compliance SOP）** | ❌ 两者属于完全不同品类的文档，不可互为替代或简单修改。 |
# | **可用性** | ✅ 新员工5秒内获取核心信息，建立积极第一印象 | ❌ 新员工需10分钟研读仍难掌握要点，易产生困惑与抵触 | **生成回答完全无法达成参考答案的业务目标**。 |
# | **改进建议** | 若需增强法律严谨性，可在参考答案末尾添加一句：“具体执行细则详见您入职后收到的《福利确认函》及HRIS系统指引。” —— 既保持温度，又预留合规接口。 | 若需生成合规文件，应剥离欢迎语境，命名为《XX公司员工福利执行细则（2024版）》，并拆分为《保险管理分册》《休假管理分册》等轻量模块，而非强行塞入单文档。 | |
#
# **最终判定：差距极大，且属于战略层面的定位错误，非技术性微调可弥合。**
# \n评估未通过，根据差距分析报告优化提示词...
# \n达到最大迭代次数，停止优化。

# %% [markdown]
# 这个自动化的迭代过程展示了 Meta Prompting 的真正效果。它将你从繁琐的手动调整中解放出来，让模型自己去探索和发现最佳的表达方式，也为更复杂的 **AI 自我改进（Self-Improvment）** 系统的设计提供了基础思路。
#
# #### 效果评测：量化你的优化成果
#
# 当你有多个版本的提示词（例如，初始版本 vs. 单次优化版 vs. 多轮迭代最终版），你如何客观地证明哪个更好呢？除了直观感受，更科学的方法是进行**量化评估**。
#
# 你可以再次利用大模型，让它扮演一个“评分员”（Grader）的角色，根据一系列标准对不同提示词生成的回答进行打分。
#
# 例如，你可以定义一个评分标准：
#
# *   **友好度 (Friendliness)**: 1-5分
# *   **结构清晰度 (Clarity)**: 1-5分
# *   **信息准确性 (Accuracy)**: 1-5分
#
# 然后，构建一个“Grader Prompt”，将评分标准和待评估的回答一起交给大模型，让它输出一个结构化的评分结果（如 JSON）。

# %%
import json
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# 设置中文字体
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# 三个质量差异明显的典型回答样本
# 差：只是简单罗列信息，没有结构和感情
poor_response = "公司福利：健康保险，家属可用。15天年假，5天病假。交通补贴500，餐饮补贴300。培训基金8000。健身房有折扣。"

# 中：有基本结构和分类，但语气平淡
medium_response = """
公司福利：
1. 💦健康和假期：
   - 健康保险（含家属）
   - 年度体检
   - 15天年假和5天病假
2. 💰补贴和激励：
   - 每月500交通补贴和300餐饮补贴
   - 8000元/年的教育培训基金
   - 合作健身房折扣
"""

# 优：结构清晰、语气友好、视觉吸引力强（直接使用我们的参考答案）
good_response = reference_answer 

# 设计更细化的评估维度
def grade_response_detailed(response_to_grade):
    grader_prompt = f"""
    【角色】你是一位经验丰富的内部沟通和员工体验评测官。
    【任务】请根据以下四个维度，对提供的“公司福利介绍”文本进行1-5分的量化评分。
    
    【评分维度】
    1.  **欢迎语气 (welcoming_tone)**: 1分表示语气冰冷生硬，5分表示非常热情、有感染力。
    2.  **内容结构化 (structuring)**: 1分表示信息混乱无序，5分表示分类清晰、逻辑性强。
    3.  **视觉吸引力 (visual_appeal)**: 1分表示枯燥乏味，5分表示善用表情符号、粗体等元素，非常吸引眼球。
    4.  **信息完整性 (completeness)**: 1分表示信息缺失严重，5分表示关键福利信息完整无缺。

    【待评估文本】
    {response_to_grade}
    ---
    【输出要求】
    请严格以JSON格式返回你的评分，不要包含任何解释。例如：
    {{"welcoming_tone": 5, "structuring": 4, "visual_appeal": 5, "completeness": 5}}
    """
    try:
        raw_output = llm.invoke(grader_prompt)
        # 提取JSON部分
        json_str = raw_output[raw_output.find('{'):raw_output.rfind('}')+1]
        return json.loads(json_str)
    except (json.JSONDecodeError, IndexError):
        # 容错处理，在无法解析时返回一个默认的低分
        return {{"welcoming_tone": 1, "structuring": 1, "visual_appeal": 1, "completeness": 1}}

# 对三个典型样本进行评分
# 注意：这里的 key 将作为图表中的标签，我们使用新视觉方案中提供的名称
scores = {
    "Original Answer": grade_response_detailed(poor_response),
    "Single Iteration Optimize": grade_response_detailed(medium_response),
    "Multi-turn Iteration Optimize": grade_response_detailed(good_response)
}

# 将 scores 转换为 DataFrame
df = pd.DataFrame(scores)
df = df.reset_index().rename(columns={'index': 'Dim'})
df_long = df.melt(id_vars='Dim', var_name='Version', value_name='Score')


# --- 单幅分组柱状图 ---
plt.figure(figsize=(10, 6))
ax = sns.barplot(
    data=df_long,
    x="Dim",        # 每个维度一组
    y="Score",
    hue="Version",  # 3 个版本并排
    palette="viridis"
)

# 为每根柱子添加数值标签
for p in ax.patches:
    height = p.get_height()
    if height == 0:          # 跳过高度为 0 的占位 patch
        continue
    ax.annotate(
        f"{height}",
        (p.get_x() + p.get_width() / 2., height),
        ha='center', va='center',
        xytext=(0, 5),
        textcoords='offset points',
        fontsize=11
    )

# 轴和标题美化
ax.set_ylim(0, 6)
ax.set_ylabel('Score (1-5)', fontsize=12)
ax.set_xlabel('')                # 隐藏 X 轴标题
ax.set_title('Evaluation', fontsize=20)
ax.tick_params(axis='x', labelsize=12)

plt.legend()       # 显示图例
plt.tight_layout()
plt.show()

# %% [markdown]
# 你可以看到，每次迭代的大模型的回复效果都有不同程度的提升。通过这种量化评估，你不仅能直观地看到每次优化带来的提升，还能将“好”或“不好”这种模糊的感觉，转化为清晰、可衡量的数据。这为你提供了一种科学的方法来验证和迭代你的提示词策略，确保每一步改进都有据可依，最终交付出真正高质量的用户体验。

# %% [markdown]
# ### 4.7 让大模型帮你打造专属“AI 裁判”
# 上一节的自动化优化循环非常强大，但它引出了一个关键的工程问题：这个循环何时停止？
# 问题的关键在于，依赖“差距大不大”这种模糊的评价是不可靠的。你需要一个“**AI裁判**”，它能依据预设的量化标准，对每次优化结果给出明确的“**✅通过**”或“**❌不通过**”结论，从而为你的自动化流程提供一个清晰、可靠的停止条件。
#
# <div align="center">
#   <a href="https://img.alicdn.com/imgextra/i3/O1CN01pi2na21tDbDRT3Jna_!!6000000005868-2-tps-1115-614.png" target="_blank">
#     <img src="https://img.alicdn.com/imgextra/i3/O1CN01pi2na21tDbDRT3Jna_!!6000000005868-2-tps-1115-614.png" width="600"/>
#     </a>
#   <p>图： 通过Meta-Prompting构造一个 “AI 裁判”，替代 analyze_gap() 方法，提升“判别”准确率。</p>
# </div>
#
#
# #### “AI 裁判” 的训练流程
# 打造“AI 裁判”的过程可以看作是在训练一个机器学习的分类器。你要打造的“AI裁判”提示词就是待训练的“模型”，而你准备的标准样本就是“数据集”。整个流程就是通过数据来“训练”你的“模型”。
# 1. **准备数据集**：首先创建一批高质量的标注样本（包含“好答案”与“坏答案”）。
# 2. **迭代“训练”**：
#    - a. 将这批数据自动按比例（如 7:3）拆分为“训练集”和“评估集”。
#    - b. 使用当前的“裁判提示词”，分别在**训练集**和**评估集**上进行“**预测**”，并记录下各自的准确率分数。
# 为什么要监控两个分数？
# 关注这两个分数的变化，能帮你判断“模型”是否出现了“过拟合”——即它只是“背会”了训练题，而对新题（评估集）的判断能力没有真正提升。
#    - c. 找出在**训练集**上判断错误的“错题”。
#    - d. 将这些“错题”连同你的分析，通过 Meta Prompting 的方式，让大模型帮你优化“裁判提示词”，生成一个新版本。
#    - e. 重复 b-d 的步骤。你可以随时**停止“训练”**。
#
# 3. **停止“训练”**：
# 在每一轮迭代中，你需要介入分析：
#    - 训练准确率和评估准确率是否都在稳步提升？
#    - 评估准确率是否停滞或突然下降（可能过拟合）
#    - 新产生的“错题”是否暴露了样本本身的模糊性或矛盾？（样本质量不好）
#
# > 注意：如果样本质量不好，导致评价标准不一致或对同类问题给出模棱两可的判断，大模型可能永远也无法构造出一个性能优秀的“AI裁判”。这时，你可以停止迭代，先去优化你的样本数据。
#
# 最终，由你来决定何时停止“训练”，并采纳在评估集上表现最好的那个版本的提示词，作为你最终的“**AI 裁判**”。
#
#
# <div align="center">
#     <a href="https://img.alicdn.com/imgextra/i4/O1CN01udzBDT1JvGoUnS4sn_!!6000000001090-2-tps-2451-831.png" target="_blank">
#     <img src="https://img.alicdn.com/imgextra/i4/O1CN01udzBDT1JvGoUnS4sn_!!6000000001090-2-tps-2451-831.png" width="800"/>
#     </a>
#   <p>图： 采用机器学习训练模型的思路来迭代 “AI 裁判”，并根据训练和评估阶段的准确率、召回率等指标的对比，决定是否结束训练。</p>
# </div>

# %% [markdown]
# #### 4.7.1 准备与拆分数据集
#
# 首先，你需要一批由你或领域专家精心标注的样本。这是整个流程的基础，也是质量的基石。

# %%
# 准备一批高质量的标注样本
# 在实际应用中，这些样本可以上传到 AI 平台（如百炼）创建评估集
labeled_samples = [
    # --- 3个样本用于“训练” ---
    {
        "id": "train_01",
        "response": "公司福利：健康保险，家属可用。15天年假，5天病假。交通补贴500，餐饮补贴300。培训基金8000。健身房有折扣。", 
        "label": "不通过", 
    },
    {
        "id": "train_02",
        "response": """公司福利包括：\n1. 健康和假期：健康保险、年度体检、15天年假和5天病假。\n2. 补贴和激励：每月500交通补贴和300餐饮补贴，以及8000元的培训基金。""", 
        "label": "不通过", 
    },
    {
        "id": "train_03",
        "response": """👋 欢迎加入！我们为你准备了超棒的福利：\n- 🏥 全面健康保险和年度体检\n- 🌴 15天年假+5天病假\n- 💰 每月交通和餐饮补贴\n- 🎓 高达8000元的培训基金\n期待与你共事！🎉""", 
        "label": "通过", 
    },
    
    # --- 2个样本用于“评估” ---
    {
        "id": "eval_01",
        "response": "我们有健康保险、年假、病假、交通和餐饮补贴、培训基金和健身折扣。", 
        "label": "不通过", 
    },
    {
        "id": "eval_02",
        "response": """你好，新同事！公司福利很棒哦：\n- 健康方面有保险和体检。\n- 假期有年假和病假。\n- 钱的方面有补贴和教育基金。\n祝你工作愉快！""", 
        "label": "通过", 
    },
]

# 按比例拆分数据集（此处为手动模拟）
# 在实际项目中，可使用 scikit-learn 等库的 train_test_split 来随机拆分
train_set = labeled_samples[:3]
eval_set = labeled_samples[3:]

# 假设你已有一个 llm.invoke 函数
# from your_llm_library import llm

# %% [markdown]
# #### 4.7.2 迭代“训练”
#
# 通过让模型不断学习“错题”，让“裁判提示词”变得越来越聪明。

# %%
# 定义一个辅助函数，用于在指定数据集上评估提示词的准确率
def evaluate_judge_prompt(judge_prompt, dataset):
    correct_predictions = 0

    misjudged_cases = [ ]

    
    for sample in dataset:
        prompt = judge_prompt.format(response_to_judge=sample["response"])
        
        # 模拟LLM调用，实际应为: predicted_label = llm.invoke(prompt)
        # 为了演示，这里手动模拟不同版本提示词的预测行为
        predicted_label = "通过" if "欢迎" in sample["response"] or "你好" in sample["response"] else "不通过" # 模拟v2版本的行为
        if "v1" in judge_prompt: # 模拟v1版本的宽松行为
             if "1." in sample["response"]: predicted_label = "通过"

        is_correct = (predicted_label == sample["label"])
        if is_correct:
            correct_predictions += 1
        else:
            misjudged_cases.append({
                "response": sample["response"],
                "current_judgment": predicted_label,
                "correct_judgment": sample["label"]
            })
            
    accuracy = correct_predictions / len(dataset)
    return accuracy, misjudged_cases

# ----------------- 迭代“训练”开始 -----------------

# a. 准备初始版的“裁判提示词” (v1.0)
judge_prompt_v1 = """
# v1
【角色】你是一位员工体验专家。
【任务】判断【待评估的回答】是否合格。
【评判标准】
1. 结构清晰: 信息分点或分类列出。
2. 信息完整: 提及核心福利。
【待评估的回答】
---
{response_to_judge}
---
【输出要求】请只回答“通过”或“不通过”。
"""

current_judge_prompt = judge_prompt_v1
max_iterations = 2 # 设置最大迭代次数，避免无限循环

for i in range(max_iterations):
    print(f"--- 第 {i+1} 轮迭代 ---")
    
    # b. 分别在训练集和评估集上“预测”并记录分数
    train_accuracy, misjudged_on_train = evaluate_judge_prompt(current_judge_prompt, train_set)
    eval_accuracy, _ = evaluate_judge_prompt(current_judge_prompt, eval_set)
    
    print(f"训练集准确率: {train_accuracy:.0%}")
    print(f"评估集准确率: {eval_accuracy:.0%}")

    # 如果训练集上已经没有错误，或者评估集准确率开始下降，你可以考虑停止
    if not misjudged_on_train:
        print("\n训练集上已无错误，训练完成。")
        break
        
    # c. 找出在训练集上判断错误的“错题”
    first_error = misjudged_on_train[0]
    print(f"\n发现错题: 模型将一个本应判为 '{first_error['correct_judgment']}' 的回答错判为 '{first_error['current_judgment']}'")

    # d. 将“错题”打包，让大模型帮你优化提示词
    judge_optimizer_prompt = f"""
    【角色】你是一位顶级的提示词工程师。
    【背景】我当前的裁判提示词在评估一个样本时犯了错误。
    
    【我当前的裁判提示词】
    ---
    {current_judge_prompt}
    ---
    
    【发生错误的案例】
    - 待评估的回答: "{first_error['response']}"
    - 我的工具的错误判断: "{first_error['current_judgment']}"
    - 我期望的正确判断: "{first_error['correct_judgment']}"
    - 我认为出错的原因是：当前标准太松，没有强调'热情友好'的语气。
    
    【任务】请重写我的裁判提示词，使其标准更严格，能修正上述错误。
    【要求】请只返回优化后的新提示词。
    """
    
    # 模拟调用优化器LLM，生成新版本的提示词
    # new_judge_prompt = llm.invoke(judge_optimizer_prompt)
    print("正在根据错题优化提示词...")
    new_judge_prompt = """
    # v2
    【角色】你是一位追求极致员工体验的内部沟通专家，眼光苛刻。
    【任务】严格判断【待评估的回答】是否合格。
    【评判标准】
    1.  **欢迎氛围 (必须满足)**: 必须有明确的、热情的欢迎语。
    2.  **结构化呈现 (必须满足)**: 必须使用列表或分段。
    【待评估的回答】
    ---
    {response_to_judge}
    ---
    【输出要求】请只回答“通过”或“不通过”。
    """
    
    # e. 更新为新版本的提示词，进入下一轮循环
    current_judge_prompt = new_judge_prompt
    print("-" * 20 + "\n")

print("\n--- 迭代结束 ---")
final_judge_prompt = current_judge_prompt
# Out:
# --- 第 1 轮迭代 ---
# 训练集准确率: 67%
# 评估集准确率: 100%
#
# 发现错题: 模型将一个本应判为 '不通过' 的回答错判为 '通过'
# 正在根据错题优化提示词...
# --------------------
#
# --- 第 2 轮迭代 ---
# 训练集准确率: 100%
# 评估集准确率: 100%
#
# 训练集上已无错误，训练完成。
#
# --- 迭代结束 ---

# %% [markdown]
# #### 4.7.3 “足够优秀”，就可以“停止训练”
# 在上面的迭代循环中，你可以清楚地看到分数的变化：
# - 第 1 轮迭代:
#
#     - 训练集准确率: 67% (v1 提示词判错了 train_02)
#     - 评估集准确率: 100% (v1 提示词恰好都判对了)
# - 第 2 轮迭代:
#
#     - 训练集准确率: 100% (v2 提示词修正了错误)
#     - 评估集准确率: 100%
#
# 在这个简单的例子中，评估准确率始终很高。但在真实场景中，你可能会看到评估准确率停滞甚至下降。</br>
# 基于以上数据，你会发现 v2 版本的提示词在训练集和评估集上都达到了100%的准确率。因此，你可以采纳 `judge_prompt_v2` 作为你最终的、经过验证的“AI裁判”。如果评估结果不理想，你可能需要回到一开始，检查并优化你的 `labeled_samples`。
#
# #### 4.7.4 用“AI裁判”指导自动化优化
# 现在你拥有了一个经过反复验证和测试的“AI裁判”（`final_judge_prompt`），可以投入使用了。</br>
# 你需要用它来替换 4.6 节中那个对比两个样本之间的差异来判断是否可用的评估环节，让整个流程变得更加严谨。
#
# **新的工作流如下：**
# 1. **生成 (Generate)**：使用当前的“生成提示词”产出一个回答。
# 2. **判决 (Judge)**：调用你训练好的“AI裁判提示词”，对回答进行“通过/不通过”的判决。
# 3. **决策与优化 (Decide & Optimize)**：
#
#     - 如果判决为“**通过**”，循环结束，优化成功。
#     - 如果判决为“**不通过**”，则将“生成提示词”、“失败的回答”以及“**AI裁判的规则书**”（也就是它的提示词）一起交给“优化器”，让它根据明确的失败标准来生成新版提示词。

# %%
import os
from langchain_community.llms import Tongyi

# # --- 1. 定义“AI裁判”与“优化器” ---
# # 最终采纳的、经过验证的“AI裁判”提示词（可以采用下面这段提示词做模拟）
# final_judge_prompt = """
# # v2
# 【角色】你是一位追求极致员工体验的内部沟通专家，眼光苛刻。
# 【任务】严格判断【待评估的回答】是否合格。
# 【评判标准】
# 1.  **欢迎氛围 (必须满足)**: 必须有明确的、热情的欢迎语。
# 2.  **结构化呈现 (必须满足)**: 必须使用列表或分段。
# 【待评估的回答】
# ---
# {response_to_judge}
# ---
# 【输出要求】请只回答“通过”或“不通过”。
# """

# 定义一个更强大的优化函数，它直接参考“裁判”的规则
def optimize_with_judge_rules(current_prompt, failed_response, judge_prompt):
    """调用LLM来根据裁判的规则优化生成提示词"""
    optimizer_prompt = f"""
    【角色】你是一位顶级的提示词工程师。
    【背景】我有一个“生成提示词”，但它生成的回答未能通过“AI裁判”的审核。
    
    【生成提示词】
    ---
    {current_prompt}
    ---
    
    【它生成的失败回答】
    ---
    {failed_response}
    ---
    
    【AI裁判的规则书 (它失败的原因)】
    ---
    {judge_prompt}
    ---
    
    【任务】
    请仔细研究“AI裁判的规则书”，并重写“生成提示词”，确保新提示词能生成一个可以通过该规则审核的回答。
    
    【要求】
    请只返回优化后的新版“生成提示词”，不要包含任何其他说明或解释。
    """
    # 真实调用LLM进行优化
    new_prompt = llm.invoke(optimizer_prompt)
    return new_prompt

# --- 2. 运行由“AI裁判”驱动的自动化优化循环 ---
current_generating_prompt = initial_prompt
max_iterations = 5 # 可以增加最大迭代次数，尽管已经加入 AI 裁判，仍需防止意外的无限循环

print("\n" + "="*30)
print("开始最终的、由“AI裁判”驱动的自动化优化流程")
print("="*30 + "\n")

for i in range(max_iterations):
    print(f"--- 最终流程：第 {i+1} 轮迭代 ---")
    
    # 1. 生成回答 (真实调用)
    prompt_for_generator = current_generating_prompt.format(retrieved_text=retrieved_text)
    generated_response = llm.invoke(prompt_for_generator)
    
    print(f"生成的回答:\n---\n{generated_response}\n---")
    
    # 2. 调用“AI裁判”进行判决 (真实调用)
    judge_prompt_filled = final_judge_prompt.format(response_to_judge=generated_response)
    judgment = llm.invoke(judge_prompt_filled)
    
    # 清理judgment，只取核心词
    judgment_cleaned = judgment.strip().replace("。", "")
    print(f"“AI裁判”的判决: {judgment_cleaned}")

    # 3. 决策
    # 使用精确的“==”判断，避免“不通过”包含“通过”的逻辑错误
    if judgment_cleaned == "通过":
        print("\n✅ 优化成功！生成的回答已通过“AI裁判”的审核。")
        break
    else:
        print("❌ 未通过审核，正在根据“裁判”的规则进行优化...")
        current_generating_prompt = optimize_with_judge_rules(
            current_generating_prompt, 
            generated_response, 
            final_judge_prompt
        )
        print("-" * 20 + "\n")
else:
    print("\n达到最大迭代次数，停止优化。")

print("\n" + "="*30)
print("最终采纳的生成提示词：")
print("="*30)
print(current_generating_prompt)
# Out:
# ==============================
# 开始最终的、由“AI裁判”驱动的自动化优化流程
# ==============================
#
# --- 最终流程：第 1 轮迭代 ---
# 生成的回答:
# ---
# 您好！欢迎加入公司！以下是您关心的福利政策汇总，清晰明了，便于您快速了解：
#
# ✅ **健康保障**
# - 全面健康保险：覆盖员工本人及直系家属（配偶、子女、父母）；
# - 年度免费体检：每年一次，含基础项目与个性化可选项。
#
# ✅ **休假安排**
# - 带薪年假：15天/年（按国家规定及司龄梯度累加，入职即享）；
# - 带薪病假：5天/年（无需提供病假条，超出部分按制度执行）。
#
# ✅ **日常补贴**
# - 交通补贴：500元/月（随工资发放，无需票据）；
# - 餐饮补贴：300元/月（直接计入企业食堂账户或发放至饭卡，亦支持外部合作餐饮平台使用）。
#
# ✅ **学习与发展**
# - 教育培训基金：最高8000元/年/人，可用于：
#   • 线上/线下专业课程（如PMP、AWS认证、语言培训等）；
#   • 购买正版专业书籍、行业报告或订阅知识平台（如Coursera、得到等）；
#   • 报考与岗位强相关的资格证书（费用报销+考试通过奖励）。
# → 申请流程简单：提交计划→直属主管审批→HR备案→结项报销。
#
# ✅ **健康生活支持**
# - 健身福利：公司已签约多家主流健身房（如威尔士、乐刻、超级猩猩等），员工凭工牌享会员价5–7折，并可参与公司组织的季度健身挑战赛，赢取额外激励。
#
# 💡 小贴士：所有福利均在入职当月起生效（体检、保险自社保参保次月起覆盖）；具体操作指南和合作机构清单，您可在入职后登录公司「E-HR福利平台」查看，或联系HRBP获取一对一协助。
#
# 如有其他个性化需求（如家属保险增员、培训基金使用咨询等），欢迎随时与我联系！祝您工作顺利，健康快乐 🌟
# ---
# “AI裁判”的判决: 通过
#
# ✅ 优化成功！生成的回答已通过“AI裁判”的审核。
#
# ==============================
# 最终采纳的生成提示词：
# ==============================
#
# 根据以下信息，回答新员工关于公司福利的问题。
#
# 【参考信息】
#
# 关于公司的福利政策，我们提供全面的健康保险，覆盖员工及其直系家属。
# 年度体检是标配。此外，每年有15天的带薪年假，以及5天的带薪病假。
# 我们还提供每月500元的交通补贴和300元的餐饮补贴。
# 为了鼓励员工成长，公司设有每年高达8000元的教育培训基金，员工可以申请用于课程学习或购买专业书籍。
# 健身方面，公司与多家健身房有合作，员工可享受折扣价。

# %% [markdown]
# “**AI裁判**”可以让你的提示词优化流程变得更可控：
# - 每当“生成提示词”产生一个新回答，就先让“AI裁判”来打分。</br>
# - **通过了，代表优化成功；没通过，就将这个“坏答案”作为新材料，继续迭代优化你的生成提示词**。</br>
#
# 你可以始终采用这种思路，先打造“裁判”，再优化“选手”。构建一个可度量、可信赖、可自动化的“**提示词优化工程**”。

# %% [markdown]
# ## 5. 推理大模型
#
# 前面所讲的提示词技巧和提示词框架可以广泛适用于通用大模型（如Qwen2.5-max、GPT-4、DeepSeek-V3），这类模型面向通用对话、知识问答、文本生成等广泛的场景。除了通用大模型，目前还有一类专门为“推理”设计的大模型——`推理大模型`。
#
# ### 5.1 什么是推理大模型?
#
# 你可能已经通过2.1节的扩展阅读了解了阿里云的推理大模型[Qwen3](https://help.aliyun.com/zh/model-studio/deep-thinking) 。为了方便本节后续调用，改写了2.1节中提供的代码，你可以尝试运行以下代码：

# %%
from openai import OpenAI
import os

def reasoning_model_response(user_prompt, system_prompt="你是一个编程助手。", model="qwen3-235b-a22b-thinking-2507"):
    """
    prompt: 用户输入的提示词
    model: 此处以 qwen3-235b-a22b-thinking-2507 为例，可按需更换推理模型名称，如：deepseek-r1
    """
    # 初始化客户端
    client = OpenAI(
        api_key=os.getenv("DASHSCOPE_API_KEY"),
        base_url=os.getenv("BASE_URL")
    )

    # 初始化状态变量
    is_answering = False

    # 发起流式请求
    completion = client.chat.completions.create(
        model=model,
        # messages=[{"role": "user", "content": prompt}],
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        stream=True,
    )

    # 打印思考过程标题
    print("\n" + "=" * 20 + "思考过程" + "=" * 20 + "\n")

    # 处理流式响应
    for chunk in completion:
        if chunk.choices:
            delta = chunk.choices[0].delta
            if hasattr(delta, 'reasoning_content') and delta.reasoning_content is not None:
                # 处理思考过程内容
                print(delta.reasoning_content, end='', flush=True)
            else:
                # 切换到答案输出模式
                if delta.content != "" and not is_answering:
                    print("\n" + "=" * 20 + "完整回复" + "=" * 20 + "\n")
                    is_answering = True
                # 处理答案内容
                if delta.content:
                    print(delta.content, end='', flush=True)

# %%
reasoning_model_response(user_prompt="你是谁？")
# Out:
# ====================思考过程====================
#
# 好的，用户问“你是谁？”，我需要先确认他的意图。可能他想了解我的身份，或者之前没有接触过我，需要自我介绍。
#
# 作为编程助手，我应该明确说明自己的角色，强调在编程方面的专长。同时，保持友好和简洁，避免信息过载。
#
# 用户可能刚接触这个平台，或者之前用过其他助手，想确认我的功能。需要突出能提供哪些帮助，比如代码编写、调试、解释等。
#
# 还要注意用口语化的中文，避免太正式。可能需要举例说明能处理的问题类型，比如不同编程语言的支持，或者具体任务如算法优化。
#
# 另外，用户可能有隐藏需求，比如测试我的反应速度或准确性，所以回答要准确且迅速。可能需要邀请用户提出具体问题，促进进一步互动。
#
# 检查有没有遗漏的关键点：身份说明、功能列举、邀请提问。确保回答结构清晰，先介绍自己，再说明能做什么，最后鼓励用户提问。
#
# 避免使用技术术语过多，保持易懂。比如“调试”可以保留，但可能需要更简单的词，不过用户问的是编程助手，应该能理解。
#
# 最后，保持回答简短，不过于冗长。用户可能希望快速得到信息，所以重点突出。
# ====================完整回复====================
#
# 你好！我是Qwen，是阿里巴巴集团旗下的通义实验室自主研发的超大规模语言模型。作为你的编程助手，我特别擅长：
#
# - **代码编写**：支持Python、Java、C++、JavaScript等主流语言
# - **调试助手**：帮你分析报错信息，定位bug
# - **技术解释**：用通俗语言讲解算法、框架原理
# - **效率工具**：代码优化建议、自动化脚本生成
#
# 比如你可以说：
# "用Python写个快速排序"
# "解释一下React的虚拟DOM"
# "这个Java报错怎么解决？"
#
# 有什么编程问题，尽管来问我吧！ 😄

# %% [markdown]
# 通过例子可以看到，推理模型相较于通用大模型多出了“`思考过程`”，就像解数学题时有人会先在草稿纸上一步步推导，而不是直接报答案，减少模型出现“拍脑袋”的错误，同时在分步思考过程中，如果某一步骤发现矛盾，还可以回头检查并重新调整思路，展示推理步骤还可以方便人们理解，顺着模型的思考路线验证逻辑。<br>
# 相较于通用大模型，推理大模型通常在解决复杂问题时更可靠，比如在数学解题、代码编写、法律案件分析等需要严谨推理的场景。并不是说推理模型一定更好，两种模型都有各自的应用场景，下表从一些典型维度对这两类模型进行了对比：<br>
#
# | 维度            | 推理模型  | 通用模型  |
# |-------------------|------------------|------------|
# | 设计目标     | 专注于**逻辑推理、多步问题求解、数学计算**等需要深度分析的任务 | 面向**通用对话、知识问答、文本生成**等广泛场景 |
# | 训练数据侧重  | 大量**数学题解、代码逻辑、科学推理**数据集增强推理能力 | 覆盖**百科、文学、对话**等多领域海量数据 |
# | 典型输出特征 | 输出包含**完整推导**步骤，注重逻辑链条的完整性 | 输出**简洁直接**，侧重结果的自然语言表达 |
# | 响应速度 | 复杂推理任务**响应较慢**（需多步计算） | 常规任务**响应更快**（单步生成为主） |
#
# 推理模型还是通用模型？如何选择？以下是一些推荐：
# - **明确的通用任务**：对于明确定义的问题，**通用模型**一般能够很好地处理。
# - **复杂任务**：对于非常复杂的任务，且需要给出相对**更精确和可靠**的答案，推荐使用**推理模型**。这些任务可能有：
#     - 模糊的任务：任务相关信息很少，你无法提供模型相对明确的指引。
#     - 大海捞针：传递大量非结构化数据，提取最相关的信息或寻找关联/差别。
#     - 调试和改进代码：需要审查并进一步调试、改进大量代码。
# - **速度和成本**：一般来说推理模型的推理时间较长，如果你对于时间和成本敏感，且任务复杂度不高，**通用模型**可能是更好的选择。<br>
#
# 当然你还可以在你的应用中结合使用两种模型：使用推理模型完成Agent的规划和决策，使用通用模型完成任务执行。

# %% [markdown]
# ### 5.2 适用于推理大模型的提示词技巧
#
# 推理模型在面对相对模糊的任务也能给出详尽且格式良好的响应。你依然可以通过**提示词技巧**保证推理大模型的推理质量的下限：<br>
# #### 技巧一：保持任务提示简洁清晰，提供足够的背景信息<br>
# 本节4.1中介绍的**清晰表达需求**同样适用于推理模型，虽然推理模型能力很强，但却不能“看穿人的想法”，你需要保持提示**简洁、清晰**，从而让推理大模型专注于核心任务。<br>

# %%
bad_prompt="""
def example(a):
  b = []
  for i in range(len(a)):
    b.append(a[i]*2)
  return sum(b)
"""

reasoning_model_response(user_prompt=bad_prompt)
# Out:
# ====================思考过程====================
#
# Okay, let's see. The user provided a function called example that takes a list a as input. The function initializes an empty list b. Then it loops through each index i in the range of the length of a. For each element a[i], it multiplies by 2 and appends to b. Finally, it returns the sum of all elements in b.
#
# Hmm, so what does this function do exactly? Let me break it down. For each element in the input list a, it doubles the element and adds it to list b. Then sums all those doubled values. Wait, but summing the doubled elements is the same as doubling the sum of the original elements. Because sum(b) would be sum(a[i]*2 for all i) which equals 2*sum(a). So instead of creating a new list and summing it, you could just compute 2*sum(a) directly. That would be more efficient, right?
#
# Let me test with an example. Suppose a is [1, 2, 3]. Then b becomes [2,4,6], sum is 12. And 2*sum(a) is 2*(6) =12. Yep, same result. So the function is equivalent to returning 2 * sum(a). The current implementation uses a loop and creates an intermediate list, which is unnecessary. So a better way would be to just compute 2*sum(a) without the loop.
#
# Wait, but maybe the user wants to see if I can optimize this. The original code is correct but not efficient. So the optimized version would be a one-liner: return 2 * sum(a). Let me check edge cases. If a is empty, sum(a) is 0, so 2*0=0, which matches the original function. If a has negative numbers, same logic applies. So yes, the optimized version works for all cases.
#
# So the answer should explain that the function doubles each element and sums them, which is equivalent to twice the sum of the original list. Then suggest the optimized code.
# ====================完整回复====================
#
# 这个函数的作用是将输入列表 `a` 中的每个元素乘以 2，然后返回所有结果的总和。实际上，这个操作等价于 **直接计算原列表总和的 2 倍**，无需创建中间列表。
#
# ### 优化建议
# 当前实现通过循环和中间列表 `b` 完成计算，但存在不必要的开销。可以简化为一行代码：
#
# ```python
# def example(a):
#     return 2 * sum(a)
# ```
#
# ### 为什么等价？
# - 原代码逻辑：`sum([a[0]*2, a[1]*2, ..., a[n]*2])`
# - 数学等价：`2*a[0] + 2*a[1] + ... + 2*a[n] = 2*(a[0] + a[1] + ... + a[n]) = 2 * sum(a)`
#
# ### 优势
# 1. **时间效率**：从 O(n) 循环 + O(n) 求和 → 直接 O(n) 求和
# 2. **空间效率**：避免创建长度为 n 的中间列表 `b`
# 3. **代码简洁性**：更直观地表达计算意图
#
# ### 测试用例验证
# ```python
# assert example([1, 2, 3]) == 12  # 原逻辑: (1*2 + 2*2 + 3*2) = 12
# assert example([]) == 0          # 空列表返回 0
# assert example([-1, 0, 1]) == 0  # 负数/零的处理
# ```

# %% [markdown]
# 通过如上示例，可以看到就算你只给推理大模型一段代码，它还是能够通过一系列的推理给出很丰富的答案，但返回的推理中可能包含了很多你不关注的信息，你可以尝试明确**任务目标**，从而获得更有针对性的建议：

# %%
prompt_A="""
如下 python 代码有什么问题？怎么优化？
def example(a):
  b = []
  for i in range(len(a)):
    b.append(a[i]*2)
  return sum(b)
"""

reasoning_model_response(user_prompt=prompt_A)
# Out:
# ====================思考过程====================
#
# 让我分析一下这段Python代码，找出问题并提出优化建议：
#
# ```python
# def example(a):
#   b = []
#   for i in range(len(a)):
#     b.append(a[i]*2)
#   return sum(b)
# ```
#
# 这段代码的功能是：
# 1. 接收一个列表a作为输入
# 2. 创建一个新列表b
# 3. 遍历列表a的每个元素，将每个元素乘以2后添加到列表b中
# 4. 返回列表b中所有元素的和
#
# 问题分析：
#
# 1. **低效的循环方式**：使用`for i in range(len(a))`然后通过索引访问元素是一种不够Pythonic的方式。更Pythonic的方式是直接遍历列表元素：`for item in a`。
#
# 2. **不必要的中间列表**：代码创建了一个中间列表b，但实际上我们只需要这个列表的和，不需要保留整个列表。这浪费了内存空间。
#
# 3. **可以使用列表推导式**：Python的列表推导式可以更简洁地表达这种操作。
#
# 4. **可以避免创建中间列表**：既然我们只需要最终的和，可以直接计算和，而不需要先创建一个中间列表。
#
# 优化方案：
#
# 方案1：使用列表推导式（仍然创建中间列表，但代码更简洁）
# ```python
# def example(a):
#     return sum([x*2 for x in a])
# ```
#
# 方案2：使用生成器表达式（不创建中间列表，更节省内存）
# ```python
# def example(a):
#     return sum(x*2 for x in a)
# ```
#
# 方案3：直接计算（最高效，但可读性可能略差）
# ```python
# def example(a):
#     return 2 * sum(a)
# ```
#
# 方案3是最优的，因为数学上 `sum(a[i]*2 for i in range(len(a)))` 等价于 `2 * sum(a)`。这避免了创建任何中间列表，也避免了重复乘法操作，是最高效的方式。
#
# 让我验证一下方案3是否正确：
# - 原始代码：`sum([a[0]*2, a[1]*2, ..., a[n-1]*2])`
# - 方案3：`2 * sum([a[0], a[1], ..., a[n-1]])`
# - 根据分配律，这两个表达式是相等的
#
# 所以，最优的优化是直接使用 `2 * sum(a)`。
#
# 总结问题：
# 1. 使用了不够Pythonic的循环方式
# 2. 创建了不必要的中间列表，浪费内存
# 3. 没有利用数学性质进行优化
#
# 优化建议：
# 1. 使用更Pythonic的循环方式或直接利用数学性质
# 2. 避免创建不必要的中间数据结构
# 3. 简化代码逻辑
#
# 最优代码：
# ```python
# def example(a):
#     return 2 * sum(a)
# ```
#
# ====================完整回复====================
#
# # 代码分析与优化建议
#
# ## 原代码问题
#
# ```python
# def example(a):
#   b = []
#   for i in range(len(a)):
#     b.append(a[i]*2)
#   return sum(b)
# ```
#
# 这段代码存在几个问题：
#
# 1. **低效的循环方式**：使用`for i in range(len(a))`然后通过索引访问元素是不够Pythonic的方式，直接遍历元素更简洁高效
#
# 2. **不必要的中间列表**：创建了列表`b`来存储中间结果，但实际上我们只需要最终的和，这浪费了内存空间
#
# 3. **未利用数学性质**：`sum(a[i]*2 for i in range(len(a)))`在数学上等价于`2 * sum(a)`，可以直接简化
#
# ## 优化方案
#
# ### 方案1：使用列表推导式（代码更简洁）
# ```python
# def example(a):
#     return sum([x*2 for x in a])
# ```
#
# ### 方案2：使用生成器表达式（节省内存）
# ```python
# def example(a):
#     return sum(x*2 for x in a)
# ```
#
# ### 方案3：最优解（最高效）
# ```python
# def example(a):
#     return 2 * sum(a)
# ```
#
# ## 推荐优化
#
# **最优解决方案是方案3**，原因：
#
# - 完全避免了创建中间列表，节省内存
# - 只需遍历列表一次（`sum(a)`内部实现）
# - 利用分配律将n次乘法简化为1次乘法
# - 代码最简洁，可读性最高
# - 性能最好，特别是对于大型列表
#
# 这个优化利用了数学性质：`sum([x*2 for x in a])` 等价于 `2 * sum(a)`，这是最本质的优化。

# %% [markdown]
# 同样地，你还可以在结合本节**4.2 限定角色和受众**、**4.3规定输出格式**等技巧进一步限定范围，确保结果符合你的预期。<br>
# 同时，如果提示词比较复杂，你可以通过**分隔符**帮助模型理解你的意图。<br>

# %%
prompt_B="""
<audience>初级Python开发者</audience>

<task>函数性能优化，优化code中的代码。</task>

<format>
如有多种优化方案请按照如下格式进行输出：
【优化方案X】
问题描述：[描述]
优化方案：[描述]
示例代码：[代码块]
</format>

<code>
def example(a):
  b = []
  for i in range(len(a)):
    b.append(a[i]*2)
  return sum(b)
</code>
"""

reasoning_model_response(user_prompt=prompt_B)
# Out:
# ====================思考过程====================
#
# 首先，我需要分析给定的代码，找出可以优化的地方。
#
# ```python
# def example(a):
#   b = []
#   for i in range(len(a)):
#     b.append(a[i]*2)
#   return sum(b)
# ```
#
# 这段代码的功能是：
# 1. 创建一个空列表b
# 2. 遍历输入列表a的所有索引
# 3. 将a中每个元素乘以2后添加到b中
# 4. 返回b中所有元素的和
#
# 我可以找出几个潜在的优化点：
#
# 1. **避免不必要的列表创建**：当前代码创建了一个中间列表b，但实际上我们只需要这个列表的和，不需要保留整个列表。可以直接计算和，而不需要存储中间结果。
#
# 2. **使用更高效的循环方式**：当前使用`range(len(a))`来遍历索引，然后通过索引访问元素。Python中更Pythonic的方式是直接遍历元素本身。
#
# 3. **使用生成器表达式或列表推导式**：Python的内置函数如sum()可以直接接受生成器表达式或列表推导式，这样可以避免创建中间列表。
#
# 4. **使用map函数**：map函数可以将函数应用于可迭代对象的每个元素，有时比循环更高效。
#
# 让我思考一下具体的优化方案：
#
# **优化方案1**：避免创建中间列表
# 当前代码创建了列表b，但实际上我们只需要b的和。我们可以直接计算和，而不存储中间结果。
#
# **优化方案2**：使用列表推导式
# 列表推导式通常比显式循环更高效，也更Pythonic。
#
# **优化方案3**：使用生成器表达式
# 生成器表达式比列表推导式更节省内存，因为它不会一次性创建整个列表。
#
# **优化方案4**：使用map函数
# map函数可以将函数应用于可迭代对象的每个元素。
#
# 让我为每个方案准备示例代码：
#
# **优化方案1**：
# ```python
# def example(a):
#     total = 0
#     for i in range(len(a)):
#         total += a[i] * 2
#     return total
# ```
#
# **优化方案2**：
# ```python
# def example(a):
#     return sum([x * 2 for x in a])
# ```
#
# **优化方案3**：
# ```python
# def example(a):
#     return sum(x * 2 for x in a)
# ```
#
# **优化方案4**：
# ```python
# def example(a):
#     return sum(map(lambda x: x * 2, a))
# ```
#
# 现在，我需要评估这些方案的优缺点，以确定哪些是最有效的优化。
#
# 1. **方案1**：避免了中间列表的创建，节省了内存。但循环方式仍然不够Pythonic。
#
# 2. **方案2**：使用列表推导式，代码更简洁。但仍然创建了中间列表，对于大型列表来说可能不够高效。
#
# 3. **方案3**：使用生成器表达式，不创建中间列表，节省内存。对于大型列表特别有用。
#
# 4. **方案4**：使用map函数，可能比循环略快，但lambda函数可能引入一些开销。在Python 3中，map返回的是迭代器，不会创建中间列表。
#
# 考虑到这些，我认为方案3和方案4是最优的，因为它们避免了创建中间列表。
#
# 不过，我应该测试一下这些方案的实际性能。但作为初步分析，我可以基于一般Python性能知识来判断。
#
# 在Python中，`sum(x * 2 for x in a)`（生成器表达式）通常比创建中间列表更高效，因为生成器是惰性计算的，不会一次性将所有元素存储在内存中。
#
# `sum(map(lambda x: x * 2, a))`也避免了中间列表，但lambda函数可能会引入一些额外开销。在某些情况下，使用`sum(map(operator.mul, a, [2]*len(a)))`可能会更快，但这可能过于复杂。
#
# 实际上，在Python中，`sum(x * 2 for x in a)`通常是最简洁且高效的。
#
# 另一个考虑是，乘以2可以简化为左移一位（`x << 1`），但这在Python中可能不会带来显著的性能提升，因为Python的整数操作已经很优化了，而且这种优化可能会降低代码可读性。
#
# 让我再思考一下：
#
# 对于数字列表，`sum(a) * 2`实际上等价于原函数！因为`sum([x*2 for x in a]) = 2 * sum(a)`。这是一个重要的数学优化。
#
# 所以，最优化的方案可能是：
#
# ```python
# def example(a):
#     return sum(a) * 2
# ```
#
# 这个方案完全避免了循环和中间计算，直接利用了数学性质。
#
# 让我验证一下：
# - 原函数：`sum([x*2 for x in a]) = 2*sum(a)`
# - 优化后：`sum(a) * 2`
#
# 是的，这两个是等价的。
#
# 所以，我应该包括这个数学优化作为最佳方案。
#
# 现在，我有以下优化方案：
#
# **优化方案1**：避免中间列表，直接计算和
# 问题：原代码创建了不必要的中间列表b
# 方案：不创建中间列表，直接累加结果
# 示例代码：
# ```python
# def example(a):
#     total = 0
#     for i in range(len(a)):
#         total += a[i] * 2
#     return total
# ```
#
# **优化方案2**：使用更Pythonic的循环方式
# 问题：使用`range(len(a))`不够Pythonic，且效率略低
# 方案：直接遍历元素而不是索引
# 示例代码：
# ```python
# def example(a):
#     total = 0
#     for x in a:
#         total += x * 2
#     return total
# ```
#
# **优化方案3**：使用生成器表达式
# 问题：原代码创建了不必要的中间列表
# 方案：使用生成器表达式避免创建中间列表
# 示例代码：
# ```python
# def example(a):
#     return sum(x * 2 for x in a)
# ```
#
# **优化方案4**：数学优化
# 问题：没有利用数学性质，进行了不必要的重复计算
# 方案：利用`sum([x*2 for x in a]) = 2*sum(a)`的性质
# 示例代码：
# ```python
# def example(a):
#     return sum(a) * 2
# ```
#
# 我认为方案4是最优的，因为它完全避免了循环，直接计算结果。
#
# 让我再检查一下：
# - 原函数：`sum([x*2 for x in a])`
# - 方案4：`sum(a) * 2`
#
# 是的，对于任何数字列表a，这两个表达式是等价的。
#
# 不过，我需要考虑a可能不是数字列表的情况。但根据函数的使用（`a[i]*2`），可以假设a是数字列表。如果a包含非数字元素，原函数也会出错，所以方案4在这种情况下也是安全的。
#
# 所以，我会提供这4个优化方案，按效果从高到低排序。
#
# 不过，我应该再思考一下这些方案的实际性能差异。
#
# 1. 方案4（数学优化）：只需要计算一次sum，然后乘以2。这是最优的。
#
# 2. 方案3（生成器表达式）：避免了中间列表，但仍然需要遍历整个列表并进行乘法操作。
#
# 3. 方案2（直接遍历元素）：比原代码更Pythonic，但仍然需要遍历和乘法。
#
# 4. 方案1（直接计算和）：比原代码节省了内存，但循环方式不够Pythonic。
#
# 所以，我应该按这个顺序列出方案。
#
# 等等，我需要确认方案4是否总是正确的。让我用一个例子验证：
#
# 假设a = [1, 2, 3]
# 原函数：b = [2, 4, 6], sum(b) = 12
# 方案4：sum(a) = 6, 6 * 2 = 12
#
# 是的，正确。
#
# 另一个例子：a = [0.5, 1.5, 2.5]
# 原函数：b = [1.0, 3.0, 5.0], sum(b) = 9.0
# 方案4：sum(a) = 4.5, 4.5 * 2 = 9.0
#
# 也是正确的。
#
# 所以，方案4是正确的，并且是最优的。
#
# 现在，我准备按照要求的格式输出优化方案。
# ====================完整回复====================
#
# # 函数性能优化方案
#
# 针对您提供的代码，我发现了几个可以优化的点。以下是几种优化方案，从效果最好的开始：
#
# 【优化方案1】
# 问题描述：原代码创建了不必要的中间列表b，这会消耗额外的内存空间，尤其当输入列表a很大时。实际上，我们只需要计算总和，不需要存储每个元素乘以2后的结果。
# 优化方案：利用数学性质`sum([x*2 for x in a]) = 2 * sum(a)`，直接计算总和再乘以2，完全避免循环和中间列表。
# 示例代码：
# ```python
# def example(a):
#     return sum(a) * 2
# ```
#
# 【优化方案2】
# 问题描述：原代码使用`range(len(a))`遍历索引，然后通过索引访问元素，这种方式不够Pythonic且效率较低。
# 优化方案：使用生成器表达式直接遍历元素，避免创建中间列表，同时代码更简洁。生成器表达式是惰性计算的，不会一次性将所有元素存储在内存中。
# 示例代码：
# ```python
# def example(a):
#     return sum(x * 2 for x in a)
# ```
#
# 【优化方案3】
# 问题描述：原代码创建了中间列表b，占用了额外的内存空间。
# 优化方案：不创建中间列表，直接在循环中累加结果，节省内存空间。
# 示例代码：
# ```python
# def example(a):
#     total = 0
#     for x in a:  # 直接遍历元素而非索引
#         total += x * 2
#     return total
# ```
#
# 【优化方案4】
# 问题描述：原代码使用索引遍历的方式不够高效，且创建了不必要的中间列表。
# 优化方案：使用map函数配合sum，避免显式循环和中间列表。在Python 3中，map返回的是迭代器，不会创建中间列表。
# 示例代码：
# ```python
# def example(a):
#     return sum(map(lambda x: x * 2, a))
# ```
#
# 对于初级Python开发者，我特别推荐【优化方案1】，因为它不仅性能最好（只需一次求和操作），而且代码最简洁易懂。当处理大型数据集时，避免创建中间列表可以显著减少内存使用并提高执行速度。

# %% [markdown]
# #### 技巧二：避免思维链提示
# 本节 4.5 中你了解到通过思维链（COT）技术让大模型深入思考提升回复效果。
# 一般来说，你无需提示推理模型“逐步思考”或“解释你的推理”，因为它们本身会进行深入的思考，你的提示可能反而限制推理模型的发挥。除非你需要大模型严格按照固定的思路去推理，这种情况很少发生。
#
# #### 技巧三：根据模型响应调整提示词
# 推理模型因其回复形式(包含**思考过程**)，天然适合你分析它的思考推理结论的过程，便于你调整提示词。
# 因此，你不需要纠结提示词是否足够完善，只需要不断与推理模型对话，过程中补充信息，完善提示词即可。
# 比如当你的描述**太抽象**或**无法准确描述**时，你可以用本节4.4讲到的**增加示例**的技巧来明确这些信息，这些示例有时可以从与模型的对话历史中挑选出来。
# 这个过程可以是重复多次的，不断尝试调整提示，让模型不断推理迭代，直到符合你的要求。

# %% [markdown]
# #### 技巧四：让推理模型成为你的“提示词教练”
#
# 在 4.6 节中，你学习了 **Meta Prompting**，即让大模型帮助你优化提示词。那么，哪种模型最适合扮演这位“教练”的角色呢？
#
# 答案是**推理模型**。
#
# 由于推理模型擅长分步思考和逻辑推导，它们在分析一个提示词的优缺点、并系统性地提出改进建议方面表现得尤为出色。它们不仅能给你一个更好的提示词，还能清晰地展示出“为什么”这样改会更好，让你在优化过程中也能学到提示词工程的精髓。
#
# 让我们重新审视 4.6 节中的例子，但这次，我们使用在 6.1 节中定义的 `reasoning_model_response` 函数来充当我们的提示词教练。

# %%
# 我们将复用 4.6 节中的公司福利场景
retrieved_text = """
关于公司的福利政策，我们提供全面的健康保险，覆盖员工及其直系家属。
年度体检是标配。此外，每年有15天的带薪年假，以及5天的带薪病假。
我们还提供每月500元的交通补贴和300元的餐饮补贴。
为了鼓励员工成长，公司设有每年高达8000元的教育培训基金，员工可以申请用于课程学习或购买专业书籍。
健身方面，公司与多家健身房有合作，员工可享受折扣价。
"""

# 初始的、比较简单的提示词
initial_prompt = f"""
根据以下信息，回答新员工关于公司福利的问题。

【参考信息】
{retrieved_text}
"""

# 假设这是通用模型的、不甚理想的输出
initial_response = """
我们公司提供全面的健康保险，覆盖员工及其家属。每年有15天带薪年假和5天病假。还有每月500元交通补贴和300元餐饮补贴。公司提供8000元的年度教育基金，并与健身房有合作折扣。
"""

# 构建我们的 Meta Prompt，请求推理模型帮助优化
meta_prompt_for_reasoning = f"""
我正在为公司的新员工答疑机器人优化一个提示词，目标是回答关于“公司福利”的问题。

这是我的第一个尝试：
---\n{initial_prompt}\n---

这是它生成的输出：
---\n{initial_response}\n---

这个输出不够好。我希望机器人的回答更具吸引力，并且结构清晰，能让新员工快速抓住重点。具体要求如下：
1.  **语气**：友好、热情，有欢迎新同事的感觉。
2.  **结构**：使用清晰的要点（比如用表情符号开头的列表）来组织内容。
3.  **内容**：将福利分为几个类别，如“健康与假期”、“补贴与激励”等。

请你扮演一位提示词工程专家，帮我重写这个提示词，以实现上述目标。
请在最终答案中，只给出优化后的提示词本身，不要包含其他解释性文字。
"""

# 使用推理模型来获取优化建议
reasoning_model_response(user_prompt=meta_prompt_for_reasoning, system_prompt="你是一位顶级的提示词工程专家。")
# Out:
# ====================思考过程====================
#
# 首先，用户要求我扮演顶级提示词工程专家，帮助优化一个提示词。目标是让新员工答疑机器人回答关于“公司福利”的问题时，更具吸引力、结构清晰。
#
# 用户提供了第一个尝试的提示词和生成的输出。输出不够好，因为：
# - 语气不够友好、热情。
# - 结构不清晰，没有使用要点或表情符号。
# - 内容没有分类。
#
# 具体要求：
# 1. **语气**：友好、热情，有欢迎新同事的感觉。
# 2. **结构**：使用清晰的要点（比如用表情符号开头的列表）来组织内容。
# 3. **内容**：将福利分为几个类别，如“健康与假期”、“补贴与激励”等。
#
# 我的任务是重写提示词。最终答案中，只给出优化后的提示词本身，不要包含其他解释性文字。
#
# 所以，我需要创建一个新的提示词，确保它：
# - 指导机器人生成热情、友好的回答。
# - 指定使用表情符号开头的列表来结构化内容。
# - 要求将福利分成类别。
#
# 参考用户提供的参考信息：
# - 全面的健康保险（覆盖员工及直系家属）
# - 年度体检
# - 15天带薪年假
# - 5天带薪病假
# - 每月500元交通补贴
# - 每月300元餐饮补贴
# - 每年8000元教育培训基金（用于课程或书籍）
# - 健身房合作折扣
#
# 在优化提示词中，我需要：
# - 明确指定语气：例如，"用热情、友好的语气，像欢迎新同事一样"。
# - 指定结构：例如，"使用表情符号开头的列表，将福利分为以下类别：健康与假期、补贴与激励、个人成长等"。
# - 确保内容分类：基于要求，类别如“健康与假期”、“补贴与激励”。我可以添加其他相关类别，但要保持简洁。例如：
#   - 健康与假期：健康保险、年度体检、年假、病假
#   - 补贴与激励：交通补贴、餐饮补贴
#   - 个人成长：教育培训基金
#   - 其他：健身房折扣（可能归入健康或单独）
#
# 用户说“如‘健康与假期’、‘补贴与激励’等”，所以我应该定义这些类别。
#
# 优化提示词的结构：
# - 开头：设置上下文，指定角色（新员工答疑机器人）。
# - 中间：详细说明如何回答，包括语气、结构、内容分类。
# - 结尾：可能提醒只基于参考信息。
#
# 关键点：
# - 语气：使用像“亲爱的同事”或“欢迎加入我们”这样的短语。
# - 结构：要求用表情符号（如❤️ for health, 💰 for money, etc.）开头列表。
# - 内容：明确类别。
#
# 草拟优化提示词：
#
# "作为公司新员工答疑机器人，请用热情、友好的语气回答关于公司福利的问题，让新员工感到欢迎。将福利分为以下类别，并用表情符号开头的列表呈现：
# - ❤️ 健康与假期：包括全面的健康保险（覆盖员工及直系家属）、年度体检、15天带薪年假和5天带薪病假。
# - 💰 补贴与激励：包括每月500元交通补贴和300元餐饮补贴。
# - 📚 个人成长：包括每年高达8000元的教育培训基金，用于课程学习或专业书籍。
# - 🏋️ 健身福利：公司与多家健身房合作，员工可享受折扣价。
# 确保回答简洁、吸引人，突出公司对员工的关怀。"
#
# 检查是否满足要求：
# - 语气：指定了"热情、友好的语气"，"让新员工感到欢迎"。
# - 结构：明确要求"用表情符号开头的列表"。
# - 内容：分成了类别：健康与假期、补贴与激励、个人成长、健身福利（我添加了健身福利作为单独类别，因为用户提到"等"，可以扩展）。
#
# 用户说“如‘健康与假期’、‘补贴与激励’等”，所以我应该保持类似。或许：
# - 健康与假期
# - 补贴与激励
# - 其他（但最好具体）
#
# 在提示词中，我应该列出类别。
#
# 确保只基于参考信息：提示词中应指定"根据以下参考信息"。
#
# 用户提供的第一个提示词有【参考信息】部分，所以我需要保留类似结构。
#
# 在优化提示词中，应该包含参考信息，但用户说"根据以下信息"，所以我需要复制参考信息部分。
#
# 看用户输入：
# "根据以下信息，回答新员工关于公司福利的问题。
#
# 【参考信息】
#
# 关于公司的福利政策，我们提供全面的健康保险，覆盖员工及其直系家属。
# 年度体检是标配。此外，每年有15天的带薪年假，以及5天的带薪病假。
# 我们还提供每月500元的交通补贴和300元的餐饮补贴。
# 为了鼓励员工成长，公司设有每年高达8000元的教育培训基金，员工可以申请用于课程学习或购买专业书籍。
# 健身方面，公司与多家健身房有合作，员工可享受折扣价。"
#
# 在优化提示词中，我应该保留【参考信息】部分，但优化指令部分。
#
# 所以，优化提示词的结构：
# - 指令部分：详细说明如何回答。
# - 【参考信息】：保持原样。
#
# 最终提示词应该以类似格式。
#
# 优化指令：
# - 开头：指定角色和语气。
# - 中间：指定结构和内容分类。
# - 结尾：可能强调关键点。
#
# 写一个草稿：
#
# "作为公司新员工答疑机器人，请用热情、友好的语气回答新员工关于公司福利的问题，营造欢迎新同事的氛围。将福利信息组织成以下清晰的类别，每个类别用表情符号开头的列表呈现：
# ❤️ **健康与假期**：包括全面的健康保险（覆盖员工及直系家属）、年度体检、15天带薪年假和5天带薪病假。
# 💰 **补贴与激励**：包括每月500元交通补贴和300元餐饮补贴。
# 📚 **个人成长**：包括每年高达8000元的教育培训基金，用于课程学习或专业书籍。
# 🏋️ **健身福利**：公司与多家健身房合作，员工可享受折扣价。
# 确保回答简洁、积极，突出公司对员工的重视和关怀。
#
# 【参考信息】
#
# 关于公司的福利政策，我们提供全面的健康保险，覆盖员工及其直系家属。
# 年度体检是标配。此外，每年有15天的带薪年假，以及5天的带薪病假。
# 我们还提供每月500元的交通补贴和300元的餐饮补贴。
# 为了鼓励员工成长，公司设有每年高达8000元的教育培训基金，员工可以申请用于课程学习或购买专业书籍。
# 健身方面，公司与多家健身房有合作，员工可享受折扣价。"
#
# 在指令中，我列出了具体福利，但参考信息已经提供了，所以指令中不需要重复细节；只需指定如何组织。
#
# 更好的方式是指令中指定类别，但不列出具体点，让模型基于参考信息填充。
#
# 例如：
# "将福利分为以下类别：健康与假期、补贴与激励、个人成长、健身福利。每个类别用表情符号开头的列表呈现，并基于参考信息描述。"
#
# 这样更灵活。
#
# 参考用户的要求："将福利分为几个类别，如“健康与假期”、“补贴与激励”等。"
#
# 所以，在提示词中，指定类别名称。
#
# 最终优化提示词：
#
# "作为公司新员工答疑机器人，请用热情、友好的语气回答新员工关于公司福利的问题，让回答充满欢迎新同事的温暖感。结构化你的回答如下：
# - 使用表情符号开头的清晰列表。
# - 将福利分为以下类别：
#   ❤️ **健康与假期**：涵盖健康保险、年度体检、年假和病假。
#   💰 **补贴与激励**：包括交通补贴和餐饮补贴。
#   📚 **个人成长**：涉及教育培训基金。
#   🏋️ **健身福利**：描述健身房合作折扣。
# 确保内容基于参考信息，回答简洁、吸引人，并突出公司对员工的关怀。
#
# 【参考信息】
#
# 关于公司的福利政策，我们提供全面的健康保险，覆盖员工及其直系家属。
# 年度体检是标配。此外，每年有15天的带薪年假，以及5天的带薪病假。
# 我们还提供每月500元的交通补贴和300元的餐饮补贴。
# 为了鼓励员工成长，公司设有每年高达8000元的教育培训基金，员工可以申请用于课程学习或购买专业书籍。
# 健身方面，公司与多家健身房有合作，员工可享受折扣价。"
#
# 在类别描述中，我用了简短提示，如"涵盖健康保险、年度体检、年假和病假"，这应该足够，因为模型会从参考信息提取。
#
# 为了更精确，可以只说类别名称，让模型自己组织。
#
# 但用户示例中，在提示词里指定了结构。
#
# 看用户第一个提示词：它只是说"根据以下信息"，没有指定结构。
#
# 在优化中，我需要详细指定。
#
# 确保语气：添加"用热情、友好的语气"。
#
# 结构：指定列表格式。
#
# 内容：指定类别。
#
# 最终，只输出提示词本身。
#
# 所以，优化后的提示词应该像这样：
#
# [指令部分]
#
# 【参考信息】
#
# [原参考信息]
#
# 现在，写正式版本。
# ====================完整回复====================
#
# 作为公司新员工答疑机器人，请用热情、友好的语气回答新员工关于公司福利的问题，营造温暖欢迎的氛围，让新同事感受到家的关怀。结构化回答如下：
# - 使用表情符号开头的清晰列表，每个类别独立呈现。
# - 将福利分为以下四个类别，基于参考信息提炼关键点：
#   ❤️ **健康与假期**：涵盖全面的健康保险（覆盖员工及直系家属）、年度体检、15天带薪年假和5天带薪病假。
#   💰 **补贴与激励**：包括每月500元交通补贴和300元餐饮补贴，助你轻松通勤与日常。
#   📚 **个人成长**：提供每年高达8000元的教育培训基金，支持课程学习或专业书籍购买。
#   🏋️ **活力生活**：公司与多家健身房合作，员工专享折扣价，保持健康活力。
# 确保回答简洁、积极，突出公司对员工的重视，避免冗长细节。
#
# 【参考信息】
#
# 关于公司的福利政策，我们提供全面的健康保险，覆盖员工及其直系家属。
# 年度体检是标配。此外，每年有15天的带薪年假，以及5天的带薪病假。
# 我们还提供每月500元的交通补贴和300元的餐饮补贴。
# 为了鼓励员工成长，公司设有每年高达8000元的教育培训基金，员工可以申请用于课程学习或购买专业书籍。
# 健身方面，公司与多家健身房有合作，员工可享受折扣价。

# %% [markdown]
# 通过上面的示例，你可以清晰地看到推理模型是如何一步步分析原始提示词的不足，并结合我们提出的要求（友好的语气、清晰的结构、生动的内容等），最终构建出一个结构更加严谨、意图更加明确的优化版提示词。
#
# 这充分展示了将合适的工具用在合适的任务上的重要性，这背后是 **任务复杂性** 与 **执行成本（时间与费用）** 之间的权衡：
#
# - **通用模型（非推理模型）**：
#     - **优势**：执行速度快，成本较低。
#     - **适用场景**：适合执行相对直接、明确的任务，例如根据一个已经优化好的提示词进行信息提取、格式转换或简单问答。
#
# - **推理模型**：
#     - **优势**：擅长处理复杂、模糊或需要深度逻辑推导的任务。
#     - **适用场景**：更适合执行“元任务”（meta-task），例如分析和优化另一个任务（即提示词本身）的定义、进行复杂的规划或调试代码。
#     - **成本**：由于需要进行多步思考，其响应时间通常更长，成本也相对更高。
#
# 在你构建自己的大模型应用时，**混合使用这两种模型**往往是实现最佳性价比的策略。你可以借鉴这种思路，构建一个“分工明确”的智能系统：
# 当任务需要深度思考或规划时，引入推理模型来充当“**规划师**”或“**分析师**”的角色，让它来分解复杂任务或优化流程；然后，将拆解后的、更简单的子任务交由**通用模型**或其他工具来高效、低成本地执行。这种协作模式，能让你在保证高质量输出的同时，有效控制应用的响应时间和运行成本。

# %% [markdown]
# ## ✅ 本节小结
#
# 通过学习本节课程，你掌握了更多**上下文工程（Context Engineering）** 的高级技巧，从设计精细的提示词到实现智能的意图路由。回顾过去两节课，我们已经为答疑机器人装备了两大核心能力：<br>
# 1. **知识填充 (通过 RAG)**：解决了模型“不知道”私有信息的问题。
# 2. **行为引导 (通过提示词与控制流)**：解决了模型“如何做”、“做什么”的问题。
# 这些技巧的共同核心，正是上下文工程的精髓：<br>
# 通过精心设计和填充模型的上下文窗口，来引导和控制其生成期望的输出——这对于你用好大模型至关重要。
#
# 实际落地大模型应用的过程中，提示词部分经常让领域专家来共同设计。因此，在你的工程代码中硬编码提示词，应该考虑调整成可配置的，甚至应用流程也可配置，这样能更方便领域专家参与提示词和整个流程的设计。阿里云百炼提供了可视化的大模型[应用构建](https://help.aliyun.com/zh/model-studio/user-guide/application-introduction#7c79befb2djg9)能力，可以在页面上完成提示词编写、整个复杂应用的流程可视化搭建，非常适合在需要非技术背景的领域专家参与的大模型应用开发项目中。
#
# 在下一节中，你将学习自动化评测方法测试答疑机器人的表现，你可以使用量化的指标来评测你通过上下文工程所做的优化效果。

# %% [markdown]
# ## 🔥 课后小测验
#
# ### 🔍 单选题
# <details>
# <summary style="cursor: pointer; padding: 12px; border: 1px solid #dee2e6; border-radius: 6px;">
# <b>以下哪个提示词要素用于明确要求大模型完成的任务❓</b>
#
# - A. 角色 (Role)
# - B. 受众 (Audience)
# - C. 任务目标 (Object)
# - D. 上下文 (Context)
#
# **【点击查看答案】**
# </summary>
#
# <div style="margin-top: 10px; padding: 15px;  border: 1px solid #dee2e6; border-radius: 0 0 6px 6px;">
#
# ✅ **参考答案：C**
# 📝 **解析**：
# - 任务目标 (Object) 明确规定了大模型需要执行的操作或达成的结果。其他选项并非直接定义任务本身。
# - 角色 (Role) 定义大模型扮演的身份，受众 (Audience) 定义目标群体，上下文 (Context) 提供背景信息。
#
#
# </div>
# </details>
#
# ---
#
#
# ### 🔍 多选题
# <details>
# <summary style="cursor: pointer; padding: 12px; border: 1px solid #dee2e6; border-radius: 6px;">
# <b>你接手了一个复杂的、用于生成代码的提示词，但缺乏相关文档。在直接修改这个“黑盒”提示词之前，你会执行哪些准备工作来确保后续优化的有效性？</b>
#
# - A. 收集模型输出不佳的具体案例（Bad Cases）。
# - B. 立即开始草拟一个全新的、更简单的替代版本。
# - C. 清晰地用文字描述出期望的输出标准和格式。
# - D. 通读整个提示词，尝试凭直觉找出逻辑漏洞。
#
# **【点击查看答案】**
# </summary>
#
# <div style="margin-top: 10px; padding: 15px; border: 1px solid #dee2e6; border-radius: 0 0 6px 6px;">
#
# ✅ **参考答案：A,C**
# 📝 **解析**：
# 本题考查在启动一个结构化优化流程前，必须具备哪些核心输入。正确的优化（如Meta Prompting）需要明确的“问题”和“目标”。
# - 选项A（坏样本）和选项C（期望输出）是定义“问题”和“目标”的关键步骤，是Meta Prompting方法的两个核心输入。
# - 选项B（推倒重来）和选项D（凭直觉修改）都是高风险低效率的方法，它们没有考虑系统的结构，也没有考虑系统的效果。"
#
# </div>
# </details>
#
#
# ---
#
#
# ### 🔍 多选题
# <details>
# <summary style="cursor: pointer; padding: 12px; border: 1px solid #dee2e6; border-radius: 6px;">
# <b>在使用推理型大模型（如qwen3-235b-a22b-thinking-2507）执行深度思考任务时。以下哪些提示词技巧是推荐的❓</b>
#
# - A. 给出简单、明确的任务指示
# - B. 补充足够的背景信息
# - C. 如有特定用户群体或特定任务要求，设定角色或受众
# - D. 必须在提示词里写“一步一步推理”或者“给出解释”，模型才会使用深度思考模式
# - E. 当描述太抽象或无法准确描述时，可以通过增加示例来明确这些信息
#
# **【点击查看答案】**
# </summary>
#
# <div style="margin-top: 10px; padding: 15px; border: 1px solid #dee2e6; border-radius: 0 0 6px 6px;">
#
# ✅ **参考答案：ABCE**
# 📝 **解析**：
# - 通常情况下，推理型大模型（如qwen3-235b-a22b-thinking-2507）无需显式要求即可通过类似“思维链”（chain of thought）的模式做深度思考。
#
# </div>
# </details>

# %% [markdown]
# ## ✉️ 评价反馈
#
# 感谢你学习阿里云大模型ACP认证课程，如果你觉得课程有哪里写得好、哪里写得不好，期待你[通过问卷提交评价和反馈](https://survey.aliyun.com/apps/zhiliao/Mo5O9vuie)。
#
# 你的批评和鼓励都是我们前进的动力。
